# %% [markdown]
# # Theoretical Foundations of Buffer Stock Saving
#
# <cite data-cite="6202365/8AH9AXN2"></cite>
#
# <p style="text-align: center;"><small><small><small>Generator: BufferStockTheory-make/notebooks_byname</small></small></small></p>
#
# [![econ-ark.org](https://img.shields.io/badge/Powered%20by-Econ--ARK-3e8acc.svg)](https://econ-ark.org/materials/BufferStockTheory)

# %% [markdown]
# <a id='interactive-dashboard'></a>
#
# [This notebook](https://econ-ark.org/BufferStockTheory/#launch) uses the [Econ-ARK/HARK](https://github.com/econ-ark/HARK) toolkit to reproduce and illustrate key results of the paper [Theoretical Foundations of Buffer Stock Saving](http://econ-ark.github.io/BufferStockTheory/BufferStockTheory).
#
# #### An [interactive dashboard](https://econ-ark.org/BufferStockStockTheory/#Dashboard) allows you to modify parameters to see how the figures change.

# %%
# This cell does some setup

# Import related generic python packages
from HARK.ConsumptionSaving.ConsIndShockModel import PerfForesightConsumerType
from copy import copy
from HARK.ConsumptionSaving.ConsIndShockModel import init_idiosyncratic_shocks as base_params
from HARK.utilities import plot_funcs, plot_funcs_der
from HARK.ConsumptionSaving.ConsIndShockModel import IndShockConsumerType
from HARK.utilities import find_gui, make_figs, determine_platform, test_latex_installation, setup_latex_env_notebook
import HARK
import numpy as np
from copy import deepcopy

# Plotting tools
import matplotlib.pyplot as plt

# Ignore some harmless but alarming warning messages
import warnings
warnings.filterwarnings("ignore")

# Code to allow a master "Generator" and derived "Generated" versions
#   - allows "$nb-Problems-And-Solutions → $nb-Problems → $nb"
Generator = True  # Is this notebook the master or is it generated?

# Whether to save the figures to Figures_dir
saveFigs = True

# Whether to draw the figures
drawFigs = True

if HARK.__version__ < '0.10.8':
    raise ImportError(
        'This notebook requires at least econ-ark v0.10.8,  please update your installation pip install -U econ-ark or conda install -c conda-forge econ-ark')

pf = determine_platform()
try:
    latexExists = test_latex_installation(pf)
except ImportError:  # windows and MacOS requires manual install
    latexExists = False

setup_latex_env_notebook(pf, latexExists)

# check if GUI is present if not then switch drawFigs to False and force saveFigs to be True
if not find_gui():
    drawFigs = False
    saveFigs = True

# Font sizes for figures
fssml=18
fsmid=22
fsbig=26

# this can be removed if we pass in saveFigs and drawFigs in every call to make('figure')
def make(figure_name, target_dir="../../Figures"):
    make_figs(figure_name, saveFigs, drawFigs, target_dir)

# %% [markdown]
# ## [The Problem](http://econ-ark.github.io/BufferStockTheory/BufferStockTheory/#The-Problem)
#
# The paper defines and calibrates a small set of parameters:
#
# | Parameter | Description | Code | Value |
# |:---:| ---         | ---  | :---: |
# | $\Gamma$ | Permanent Income Growth Factor | $\texttt{PermGroFac}$ | 1.03 |
# | $\mathsf{R}$ | Interest Factor | $\texttt{Rfree}$ | 1.04 |
# | $\beta$ | Time Preference Factor | $\texttt{DiscFac}$ | 0.96 |
# | $\rho$ | Coeﬃcient of Relative Risk Aversion| $\texttt{CRRA}$ | 2 |
# | $\wp$ | Probability of Unemployment | $\texttt{UnempPrb}$ | 0.005 |
# | $\theta^{\large u}$ | Income when Unemployed | $\texttt{IncUnemp}$ | 0. |
# | $\sigma_\psi$ | Std Dev of Log Permanent Shock| $\texttt{PermShkStd}$ | 0.1 |
# | $\sigma_\theta$ | Std Dev of Log Transitory Shock| $\texttt{TranShkStd}$ | 0.1 |
#
# that define the preferences and environment of microeconomic consumers as detailed below.
#
# The objective of such a consumer with a horizon of $n$ periods is to maximize the value obtained from the stream of consumption __**c**__ from period $t=T-n$ to a terminal period $T$:
#
# \begin{equation}
# \mathbf{v}_{t} = \sum_{i=0}^{n} \beta^{n}\mathrm{u}(\mathbf{c}_{t+n})
# \end{equation}
#
# The infinite-horizon solution to the model is defined as the limit of the solution in the first period of life $\mathrm{c}_{T-n}$ as the horizon $n$ goes to infinity.

# %% [markdown]
# ### Details
# For a microeconomic consumer who begins period $t$ with __**m**__arket resources boldface $\mathbf{m}_{t}$ (=net worth plus current income), the amount that remains after __**c**__onsumption of $\mathbf{c}_{t}$ will be end-of-period __**a**__ssets $\mathbf{a}_{t}$,
#
# <!-- Next period's 'Balances' $B_{t+1}$ reflect this period's $\mathbf{a}_{t}$ augmented by return factor $R$:-->

# %% [markdown]
# \begin{eqnarray}
# \mathbf{a}_{t}   &=&\mathbf{m}_{t}-\mathbf{c}_{t}. \notag
# \end{eqnarray}
#
# The consumer's __**p**__ermanent noncapital income $\mathbf{p}$ grows by a predictable factor $\Gamma$ and is subject to an unpredictable multiplicative shock $\mathbb{E}_{t}[\psi_{t+1}]=1$,
#
# \begin{eqnarray}
# \mathbf{p}_{t+1} & = & \mathbf{p}_{t} \Gamma \psi_{t+1}, \notag
# \end{eqnarray}
#
# and, if the consumer is employed, actual income is permanent income multiplied by a transitory shock $\theta^{\large e}$.  There is also a probability $\wp$ that the consumer will be temporarily unemployed and experience income of $\theta^{\large u}  = 0$.  We construct $\theta^{\large e}$ so that its mean value is $1/(1-\wp)$ because in that case the mean level of the transitory shock (accounting for both unemployed and employed states) is exactly
#
# \begin{eqnarray}
# \mathbb{E}_{t}[\theta_{t+1}] & = & \theta^{\large{u}}  \times \wp + (1-\wp) \times \mathbb{E}_{t}[\theta^{\large{e}}_{t+1}] \notag
# \\ & = & 0 \times \wp + (1-\wp) \times 1/(1-\wp)  \notag
# \\ & = & 1. \notag
# \end{eqnarray}
#
#   We can combine the unemployment shock $\theta^{\large u}$ and the transitory shock to employment income $\theta^{\large e}$ into $\theta _{t+1}$, so that next period's market resources are
# \begin{eqnarray}
#     \mathbf{m}_{t+1} &=& \mathbf{a}_{t}\mathsf{R} +\mathbf{p}_{t+1}\theta_{t+1}.  \notag
# \end{eqnarray}

# %% [markdown]
# When the consumer has a CRRA utility function $u(\mathbf{c})=\frac{\mathbf{c}^{1-\rho}}{1-\rho}$, the paper shows that the problem can be written in terms of ratios (nonbold font) of level (bold font) variables to permanent income, e.g. $m_{t} \equiv \mathbf{m}_{t}/\mathbf{p}_{t}$, and the Bellman form of [the problem reduces to](https://econ-ark.github.io/BufferStockTheory/#The-Related-Problem):
#
# \begin{eqnarray*}
# v_t(m_t) &=& \max_{c_t}~~ u(c_t) + \beta~\mathbb{E}_{t} [(\Gamma\psi_{t+1})^{1-\rho} v_{t+1}(m_{t+1}) ] \\
# & s.t. & \\
# a_t &=& m_t - c_t \\
# m_{t+1} &=& a_t \mathsf{R}/(\Gamma \psi_{t+1}) + \theta_{t+1} \\
# \end{eqnarray*}

# %%
# Define a dictionary with baseline parameter values

# Import default parameter values (init_idiosyncratic_shock)
from HARK.ConsumptionSaving.ConsIndShockModel import init_idiosyncratic_shocks as base_params

# Set the parameters for the baseline results in the paper
# using the variable names defined in the cell above
base_params['PermGroFac'] = [1.03]  # Permanent income growth factor
base_params['Rfree']      = Rfree = 1.04  # Interest factor on assets
base_params['DiscFac']    = DiscFac = 0.96  # Time Preference Factor
base_params['CRRA']       = CRRA = 2.00  # Coefficient of relative risk aversion
# Probability of unemployment (e.g. Probability of Zero Income in the paper)
base_params['UnempPrb']   = UnempPrb = 0.005
base_params['IncUnemp']   = IncUnemp = 0.0   # Induces natural borrowing constraint
base_params['PermShkStd'] = [0.1]   # Standard deviation of log permanent income shocks
base_params['TranShkStd'] = [0.1]   # Standard deviation of log transitory income shocks

# %%
# Uninteresting housekeeping and details
# Make global variables for the things that were lists above -- uninteresting housekeeping
PermGroFac, PermShkStd, TranShkStd = base_params['PermGroFac'][0], base_params['PermShkStd'][0], base_params['TranShkStd'][0]

# Some technical settings that are not interesting for our purposes
base_params['LivPrb']      = [1.0]   # 100 percent probability of living to next period
base_params['CubicBool']   = True    # Use cubic spline interpolation
base_params['T_cycle']     = 1       # No 'seasonal' cycles
base_params['BoroCnstArt'] = None    # No artificial borrowing constraint

# %% [markdown]
# ## Convergence of the Consumption Rules
#
# Under the given parameter values, [the paper's first figure](https://econ-ark.github.io/BufferStockTheory/#Convergence-of-the-Consumption-Rules) depicts the successive consumption rules that apply in the last period of life $(c_{T}(m))$, the second-to-last period, and earlier periods $(c_{T-n})$.  The consumption function to which these converge is $c(m)$:
#
# $$
# c(m) = \lim_{n \uparrow \infty} c_{T-n}(m) \notag
# $$

# %%
# Create a buffer stock consumer instance by invoking the IndShockConsumerType class
# with the built-in parameter dictionary "base_params"

# Construct finite horizon agent with baseline parameters
baseAgent_Fin = IndShockConsumerType(**base_params)
baseAgent_Fin.cycles = 100   # Set finite horizon (T = 100)

baseAgent_Fin.solve(verbose=0)        # Solve the model
baseAgent_Fin.unpack('cFunc')  # Make the consumption function easily accessible

# %%
# Plot the different consumption rules for the different periods

mPlotMin = 0
mLocCLabels = 9.6  # Defines horizontal limit of figure
mPlotTop = 6.5    # Defines maximum m value where functions are plotted
mPts = 1000      # Number of points at which functions are evaluated

mBelwLabels = np.linspace(mPlotMin, mLocCLabels-0.1, mPts)  # Range of m below loc of labels
m_FullRange = np.linspace(mPlotMin, mPlotTop, mPts)        # Full plot range
# c_Tm0  defines the last period consumption rule (c=m)
c_Tm0 = m_FullRange
# c_Tm1 defines the second-to-last period consumption rule
c_Tm1 = baseAgent_Fin.cFunc[-2](mBelwLabels)
c_Tm5 = baseAgent_Fin.cFunc[-6](mBelwLabels)  # c_Tm5 defines the T-5 period consumption rule
c_Tm10 = baseAgent_Fin.cFunc[-11](mBelwLabels)  # c_Tm10 defines the T-10 period consumption rule
# c_Limt defines limiting inﬁnite-horizon consumption rule
c_Limt = baseAgent_Fin.cFunc[0](mBelwLabels)
plt.figure(figsize=(12, 9))
plt.plot(mBelwLabels, c_Limt, color="black")
plt.plot(mBelwLabels, c_Tm1, color="black")
plt.plot(mBelwLabels, c_Tm5, color="black")
plt.plot(mBelwLabels, c_Tm10, color="black")
plt.plot(m_FullRange, c_Tm0, color="black")
plt.xlim(0, 11)
plt.ylim(0, 7)
plt.text(7.0, 6.0, r'$c_{T   }(m) = 45$ degree line', fontsize=22, fontweight='bold')
plt.text(mLocCLabels, 5.3, r'$c_{T-1 }(m)$', fontsize=22, fontweight='bold')
plt.text(mLocCLabels, 2.6, r'$c_{T-5 }(m)$', fontsize=22, fontweight='bold')
plt.text(mLocCLabels, 2.1, r'$c_{T-10}(m)$', fontsize=22, fontweight='bold')
plt.text(mLocCLabels, 1.7, r'$c(m)       $', fontsize=22, fontweight='bold')
plt.arrow(6.9, 6.05, -0.6, 0, head_width=0.1, width=0.001,
          facecolor='black', length_includes_head='True')
plt.tick_params(labelbottom=False, labelleft=False, left='off',
                right='off', bottom='off', top='off')
plt.text(0, 7.05, "$c$", fontsize=26)
plt.text(11.1, 0, "$m$", fontsize=26)
# Save the figures in several formats

make('cFuncsConverge')  # Comment out if you want to run uninterrupted
# Out:
# Saving figure cFuncsConverge in ../../Figures

# %% [markdown]
# Use the [interactive dashboard](#interactive-dashboard) to explore the effects of changes in patience, risk aversion, or risk

# %% [markdown]
# ## Factors and Conditions
#
# ### [The Finite Human Wealth Condition](http://econ-ark.github.io/BufferStockTheory/#Human-Wealth)
#
# Human wealth for a perfect foresight consumer is the present discounted value of future income:
#
# \begin{eqnarray}\notag
# \mathbf{h}_{t} & = & \mathbb{E}_{t}[\mathbf{p}_{t} + \mathsf{R}^{-1} \mathbf{p}_{t+1} + \mathsf{R}^{2} \mathbf{p}_{t+2} ... ] \\ \notag
#       & = & \mathbf{p}_{t} \left(1 + (\Gamma/\mathsf{R}) + (\Gamma/\mathsf{R})^{2} ... \right)
# \end{eqnarray}
# which approaches infinity as the horizon extends if $\Gamma/\mathsf{R} \geq 1$.  We say that the 'Finite Human Wealth Condition' [(FHWC)](https://econ-ark.github.io/BufferStockTheory/#FHWC) holds if
# $0 \leq (\Gamma/\mathsf{R}) < 1$.

# %% [markdown]
# ### [Absolute Patience and the AIC](https://econ-ark.github.io/BufferStockTheory/#AIC)
#
# The paper defines the Absolute Patience Factor [(APF)](https://econ-ark.github.io/BufferStockTheory/#APF) as being equal to the ratio $\mathbf{c}_{t+1}/\mathbf{c}_{t}$ for a perfect foresight consumer.  The Old English character <span style="font-size:larger;">"&#222;"</span> used for this object in the paper cannot currently be rendered conveniently in Jupyter notebooks, so we will substitute $\Phi$ here:
#
# \begin{equation}
# \Phi = (\mathsf{R} \beta)^{1/\rho}
# \end{equation}
#
# If $\Phi = 1$, a perfect foresight consumer will spend at exactly the level of $\mathbf{c}$ that can be sustained perpetually (given their current and future resources).  If $\Phi < 1$ (the consumer is 'absolutely impatient'; or, 'the absolute impatience condition holds'), the consumer is consuming more than the sustainable amount, so consumption will fall, and if the consumer is 'absolutely patient' with $\Phi > 1$ consumption will grow over time.

# %% [markdown]
# ### [Growth Patience and the GICRaw](https://econ-ark.github.io/BufferStockTheory/#GIC)
#
# For a [perfect foresight consumer](https://www.econ2.jhu.edu/people/ccarroll/public/lecturenotes/consumption/PerfForesightCRRA), whether the ratio $c$=__**c**__/__**p**__ is rising, constant, or falling depends on the relative growth rates of consumption and permanent income; that ratio is measured by the [Perfect Foresight Growth Patience Factor](https://econ-ark.github.io/BufferStockTheory/#PFGPF):
#
# \begin{eqnarray}
# \Phi_{\Gamma} & = & \Phi/\Gamma
# \end{eqnarray}
# and whether the $c$ is falling or rising over time depends on whether $\Phi_{\Gamma}$ is below or above 1.
#
# An analogous condition can be defined when there is uncertainty about permanent income.  Defining $\tilde{\Gamma} = (\mathbb{E}[\psi^{-1}])^{-1}\Gamma$, the 'Growth Impatience Condition' [(GICRaw)](https://econ-ark.github.io/BufferStockTheory/#GIC) determines whether, \textit{in expectation}, the stochastic value of $c$ is rising, constant, or falling over time:
# \begin{eqnarray}
#   \Phi/\tilde{\Gamma} & < & 1
# \end{eqnarray}

# %% [markdown]
# ### [The Finite Value of Autarky Condition (FVAC)](https://econ-ark.github.io/BufferStockTheory/#Autarky-Value)

# %% [markdown]
# The paper [shows](https://econ-ark.github.io/BufferStockTheory/#Autarky-Value) that a consumer who planned to spend his permanent income $\{ \mathbf{p}_{t}, \mathbf{p}_{t+1}, ...\} $ in every period would have value defined by
#
# \begin{equation*}
# \mathbf{v}_{t}^{\text{autarky}} = u(\mathbf{p}_{t})\left(\frac{1}{1-\beta \Gamma^{1-\rho} \mathbb{E}[\psi^{1-\rho}]}\right)
# \end{equation*}
#
# and defines the 'Finite Value of Autarky Condition' as the requirement that the denominator be a positive finite number:
#
# \begin{equation*}
# \beta \Gamma^{1-\rho} \mathbb{E}[\psi^{1-\rho}] < 1
# \end{equation*}

# %% [markdown]
# ### [The Weak Return Impatience Condition (WRIC)](https://econ-ark.github.io/BufferStockTheory/#WRIC)
#
# The [Return Impatience Condition](https://econ-ark.github.io/BufferStockTheory/#RIC) $\Phi/\mathsf{R} < 1$ has long been understood to be required for the perfect foresight model to have a nondegenerate solution (a common special case is when $\rho=1$; in this case $\Phi = \mathsf{R} \beta$ so $\Phi<1$ reduces to $\beta < \mathsf{R}$).
#
# If the RIC does not hold, the consumer is so patient that the optimal consumption function approaches zero as the horizon extends indefinitely.
#
# When the probability of unemployment is $\wp$, the paper articulates an analogous (but weaker) condition:
#
# \begin{eqnarray}
#  \wp^{1/\rho} \Phi/\mathsf{R} & < & 1
# \end{eqnarray}

# %% [markdown]
# # Key Results
#
# ## [Nondegenerate Solution Requires FVAC and WRIC](https://econ-ark.github.io/BufferStockTheory/#Sufficient-Conditions-For-Nondegenerate-Solution)
#
# A main result of the paper is that the conditions required for the model to have a nondegenerate solution ($0 < c(m) < \infty$ for feasible $m$) are that the Finite Value of Autarky (FVAC) and Weak Return Impatience Condition (WRIC) hold.

# %% [markdown]
# ## [Natural Borrowing Constraint limits to Artificial Borrowing Constraint](https://econ-ark.github.io/BufferStockTheory/#The-Liquidity-Constrained-Solution-as-a-Limit)

# %% [markdown]
# Defining $\chi(\wp)$ as the consumption function associated with any particular value of $\wp$, and defining $\hat{\chi}$ as the consumption function that would apply in the absence of the zero-income shocks but in the presence of an 'artificial' borrowing constraint requiring $a \geq 0$ (_a la_ Deaton (1991)), the paper shows that
#
# \begin{eqnarray}
# \lim_{\wp \downarrow 0}~\chi(\wp) & = & \hat{\chi}
# \end{eqnarray}
#
# That is, as $\wp$ approaches zero the problem with uncertainty becomes identical to the problem that instead has constraints.  (See [Precautionary Saving and Liquidity Constraints](https://econ-ark.github.io/LiqConstr) for a full treatment of the relationship between precautionary saving and liquidity constraints).

# %% [markdown]
# ## [$c(m)$ can be Finite Even When Human Wealth Is Infinite](https://econ-ark.github.io/BufferStockTheory/#When-The-GICRaw-Fails)
#
# In the perfect foresight model, if $\mathsf{R} < \Gamma$ the PDV of future labor income approaches infinity and so the limiting consumption function is $c(m) = \infty$ for all $m$.  Many models have no well-defined solution when human wealth is infinite.
#
# The presence of uncertainty changes this: Even when limiting human wealth is infinite, the limiting consumption function is finite for all values of $m$.
#
# This is because uncertainty imposes a "natural borrowing constraint" that deters the consumer from borrowing against their unbounded (but uncertain) future labor income.

# %% [markdown]
# A [table](https://econ-ark.github.io/BufferStockTheory/#Sufficient-Conditions-For-Nondegenerate-Solution) puts this result in the context of implications of other conditions and restrictions.

# %% [markdown]
# ## [Unique and Stable Values of $\mRat$](https://econ-ark.github.io/BufferStockTheory/#Unique-Stable-Points)
#
# Assuming that the **FVAC** and **WRIC** hold so that the problem has a nondegenerate solution, under more stringent conditions its dynamics may also exhibit stability.  Two particularly useful kinds of stability are existence of a 'target' value of market resources $\Trg{\mRat}$ and a 'pseudo-steady-state' value $\StE{\mRat}$.
#
# ### [If the GIC-Nrm Holds, $\exists$ a finite 'target' $\Trg{\mRat}$](https://econ-ark.github.io/BufferStockTheory/#onetarget)
#
# Section [Individual Target Wealth](https://econ-ark.github.io/BufferStockTheory/#onetarget) shows that, under parameter values for which the limiting consumption function exists, if the GICRaw holds then there will be a value $\Trg{m}$ such that:
#
# \begin{eqnarray*}
# \mathbb{E}[m_{t+1}] & > & m_{t}~\text{if $m_{t} < \Trg{m}$} \\
# \mathbb{E}[m_{t+1}] & < & m_{t}~\text{if $m_{t} > \Trg{m}$} \\
# \mathbb{E}[m_{t+1}] & = & m_{t}~\text{if $m_{t} = \Trg{m}$}
# \end{eqnarray*}
#
# [An equation](https://econ-ark.github.io/BufferStockTheory/#mTargImplicit) in the paper tells us that if $\mRat_{t}=\Trg{m}$ then:
# \begin{align}
# (\Trg{\mNrm}-\cFunc(\Trg{\mNrm}))\bar{\RNrm}+1 & = \Trg{\mNrm}
# %\\ \Trg{\mNrm}(1-\bar{\RNrm}^{-1})+\bar{\RNrm}^{-1} & = \Trg{\cNrm}
# %\\ \Trg{\cNrm} & = \Trg{\mNrm} - (\Trg{\mNrm} - 1)\bar{\RNrm}^{-1}
# \end{align}
# which can be solved numerically for the unique $\mNrm$ that satisfies it.
#
# ### [If the GIC Holds, $\exists$ a finite 'pseudo-steady-state' $\StE{\mRat}$](https://econ-ark.github.io/BufferStockTheory/#Collective-Stability)
#
# Section [Collective Stability and the Pseudo-Steady-State](https://econ-ark.github.io/BufferStockTheory/#Collective-Stability) shows that, under parameter values for which the limiting consumption function exists, if the **GIC** holds then there will be a value $\Trg{m}$ such that:
#
# \begin{eqnarray*}
# \mathbb{E}_{t}[\mRatBF_{t+1}/\mRatBF_{t}] & > & \Gamma~\text{if $m_{t} < \StE{m}$} \\
# \mathbb{E}_{t}[\mRatBF_{t+1}/\mRatBF_{t}] & < & \Gamma~\text{if $m_{t} > \StE{m}$} \\
# \mathbb{E}_{t}[\mRatBF_{t+1}/\mRatBF_{t}] & = & \Gamma~\text{if $m_{t} = \StE{m}$}
# \end{eqnarray*}
#
# [An equation](https://econ-ark.github.io/BufferStockTheory/#balgrostableSolve) in the paper tells us that if $\mRat_{t}=\StE{m}$ then:
# \begin{align}
# (\StE{\mNrm}-\cFunc(\StE{\mNrm}))\RNrm+1 & = \StE{\mNrm}
# \end{align}
# which can be solved numerically for the unique $\StE{\mNrm}$ that satisfies it.
#
#
# ### [Example With Finite Pseudo-Steady-State $\StE{\mRat}$ But Infinite Target Wealth $\Trg{\mRat}$](https://econ-ark.github.io/BufferStockTheory/#GICNrmFailsButGICRawHolds)
#
# [A figure](https://econ-ark.github.io/BufferStockTheory/#GICNrmFailsButGICRawHolds) depicts a solution when the **FVAC** (Finite Value of Autarky Condition) and **WRIC** hold (so that the model has a solution), the **GIC** holds, so the model has a pseudo-steady-state $\StE{\mRat}$, but the **GIC-Nrm** fails, so the model does not have an individual target wealth ratio $\Trg{\mRat}$ (or, rather, the target wealth ratio is infinity, as can be seen by the fact that the level of $c$ is always below the level that would keep $\mathbb{E}_{t}[\Delta \mRat_{t+1}] = 0$)
#
# This example was constructed by quadrupling the variance of the permanent shocks from the baseline parameterization

# %%
# GICNrmFailsButGICRawHolds Example
GICNrmFailsButGICRawHoldsDict = dict(base_params)
GICNrmFailsButGICRawHoldsDict['PermShkStd'] = [0.2] # Increase patience by increasing risk

# Because we are trying to solve a problem very close to the critical patience values
# be sure to do it with extra precision

# Solve with twice the normal number of gridpoints
GICNrmFailsButGICRawHoldsDict['aXtraMax'] = base_params['aXtraCount'] * 2

# Solve over a four times larger range 
GICNrmFailsButGICRawHoldsDict['aXtraCount'] = base_params['aXtraCount'] * 4

GICNrmFailsButGICRawHolds = IndShockConsumerType(
    cycles=0, # cycles=0 makes this an infinite horizon consumer
    verbose=3, # by default, check conditions won't print out any information
    **GICNrmFailsButGICRawHoldsDict)

# Solve to a tighter than usual degree of error tolerance
GICNrmFailsButGICRawHolds.tolerance = GICNrmFailsButGICRawHolds.tolerance/100

# The check_conditions method does what it sounds like it would
# verbose=0: Print nothing;
# verbose=3: Print all available info

GICNrmFailsButGICRawHolds.solve(verbose=2)
# Out:
# The value of the Absolute Patience Factor (APF) for the supplied parameter values satisfies the Absolute Impatience Condition.
#   Because the APF < 1, the absolute amount of consumption is expected to fall over time.
# The value of the Return Patience Factor for the supplied parameter values satisfies the Return Impatience Condition.
#   Therefore, the limiting consumption function is not c(m)=0 for all m
# The Finite Human wealth factor value for the supplied parameter values satisfies the Finite Human Wealth Condition.
#   Therefore, the limiting consumption function is not c(m)=Infinity
# and human wealth normalized by permanent income is 104.00000000000037
# and the PDV of future consumption growth is 25.48999599679675
#
# The given parameter values violate the Normalized Growth Impatience Condition; the GPFNrm is: 1.0069735758414424
#  Therefore, a target ratio of individual market resources to individual permanent income does not exist.  (see https://econ-ark.github.io/BufferStockTheory//#onetarget for more).
#
# The value of the Growth Patience Factor for the supplied parameter values satisfies the Perfect Foresight Growth Impatience Condition.
#   Therefore, for a perfect foresight consumer, the ratio of individual wealth to permanent income will fall indefinitely.
#
# The value of the Mortality Adjusted Aggregate Growth Patience Factor for the supplied parameter values satisfies the Mortality Adjusted Aggregate Growth Imatience Condition; the value of the GPFAggLivPrb is: 0.9700967764502365
#   Therefore, a target level of the ratio of aggregate market resources to aggregate permanent income exists (see https://econ-ark.github.io/BufferStockTheory//#WRIC for more).
#
#
# The Weak Return Patience Factor value for the supplied parameter values satisfies the Weak Return Impatience Condition; the WRPF is 0.06793662204867575.
#   Therefore, a nondegenerate solution exists if the FVAC is also satisfied.  (see https://econ-ark.github.io/BufferStockTheory//#WRIC for more)
#
#
# The Value of Autarky Factor (VAF) for the supplied parameter values satisfies the Finite Value of Autarky Condition; the VAF is 0.9248434395252375
#   Therefore, a nondegenerate solution exists if the WRIC also holds; see https://econ-ark.github.io/BufferStockTheory//#Conditions-Under-Which-the-Problem-Defines-a-Contraction-Mapping
#
# Thorn = APF            = 0.999200
# RPF                    = 0.960769
# FHWF                   = 1.009709
# GPFNrm                 = 1.006974
# GPFRaw                 = 0.970097
# GPFAggLivPrb           = 0.970097
# VAF                    = 0.924843
# WRPF                   = 0.067937
# PermGroFacAdj          = 0.992280
# uInvEpShkuInv          = 0.963379
# DiscFacGPFNrmMax       = 0.946749
# DiscFacGPFAggLivPrbMax = 1.020096
# The value of the Absolute Patience Factor (APF) for the supplied parameter values satisfies the Absolute Impatience Condition.
#   Because the APF < 1, the absolute amount of consumption is expected to fall over time.
# The value of the Return Patience Factor for the supplied parameter values satisfies the Return Impatience Condition.
#   Therefore, the limiting consumption function is not c(m)=0 for all m
# The Finite Human wealth factor value for the supplied parameter values satisfies the Finite Human Wealth Condition.
#   Therefore, the limiting consumption function is not c(m)=Infinity
# and human wealth normalized by permanent income is 104.00000000000037
# and the PDV of future consumption growth is 25.48999599679675
#
# The given parameter values violate the Normalized Growth Impatience Condition; the GPFNrm is: 1.0069735758414424
#  Therefore, a target ratio of individual market resources to individual permanent income does not exist.  (see https://econ-ark.github.io/BufferStockTheory/#onetarget for more).
#
# The value of the Growth Patience Factor for the supplied parameter values satisfies the Perfect Foresight Growth Impatience Condition.
#   Therefore, for a perfect foresight consumer, the ratio of individual wealth to permanent income will fall indefinitely.
#
# The value of the Mortality Adjusted Aggregate Growth Patience Factor for the supplied parameter values satisfies the Mortality Adjusted Aggregate Growth Imatience Condition; the value of the GPFAggLivPrb is: 0.9700967764502365
#   Therefore, a target level of the ratio of aggregate market resources to aggregate permanent income exists (see https://econ-ark.github.io/BufferStockTheory/#WRIC for more).
#
#
# The Weak Return Patience Factor value for the supplied parameter values satisfies the Weak Return Impatience Condition; the WRPF is 0.06793662204867575.
#   Therefore, a nondegenerate solution exists if the FVAC is also satisfied.  (see https://econ-ark.github.io/BufferStockTheory/#WRIC for more)
#
#
# The Value of Autarky Factor (VAF) for the supplied parameter values satisfies the Finite Value of Autarky Condition; the VAF is 0.9248434395252375
#   Therefore, a nondegenerate solution exists if the WRIC also holds; see https://econ-ark.github.io/BufferStockTheory/#Conditions-Under-Which-the-Problem-Defines-a-Contraction-Mapping
#
# Thorn = APF            = 0.999200
# RPF                    = 0.960769
# FHWF                   = 1.009709
# GPFNrm                 = 1.006974
# GPFRaw                 = 0.970097
# GPFAggLivPrb           = 0.970097
# VAF                    = 0.924843
# WRPF                   = 0.067937
# PermGroFacAdj          = 0.992280
# uInvEpShkuInv          = 0.963379
# DiscFacGPFNrmMax       = 0.946749
# DiscFacGPFAggLivPrbMax = 1.020096
# Finished cycle # 000001 in  0.012403 seconds, solution distance = 1.000e+02
# Finished cycle # 000002 in  0.061206 seconds, solution distance = 4.895e+01
# Finished cycle # 000003 in  0.026696 seconds, solution distance = 1.630e+01
# Finished cycle # 000004 in  0.025753 seconds, solution distance = 8.136e+00
# Finished cycle # 000005 in  0.026549 seconds, solution distance = 4.872e+00
# Finished cycle # 000006 in  0.025505 seconds, solution distance = 3.240e+00
# Finished cycle # 000007 in  0.036110 seconds, solution distance = 2.307e+00
# Finished cycle # 000008 in  0.030126 seconds, solution distance = 1.725e+00
# Finished cycle # 000009 in  0.026364 seconds, solution distance = 1.337e+00
# Finished cycle # 000010 in  0.029106 seconds, solution distance = 1.065e+00
# Finished cycle # 000011 in  0.024378 seconds, solution distance = 8.679e-01
# Finished cycle # 000012 in  0.027231 seconds, solution distance = 7.200e-01
# Finished cycle # 000013 in  0.025004 seconds, solution distance = 6.063e-01
# Finished cycle # 000014 in  0.026989 seconds, solution distance = 5.170e-01
# Finished cycle # 000015 in  0.027245 seconds, solution distance = 4.457e-01
# Finished cycle # 000016 in  0.031761 seconds, solution distance = 3.877e-01
# Finished cycle # 000017 in  0.028072 seconds, solution distance = 3.401e-01
# Finished cycle # 000018 in  0.028001 seconds, solution distance = 3.004e-01
# Finished cycle # 000019 in  0.025691 seconds, solution distance = 2.671e-01
# Finished cycle # 000020 in  0.025384 seconds, solution distance = 2.388e-01
# Finished cycle # 000021 in  0.026724 seconds, solution distance = 2.145e-01
# Finished cycle # 000022 in  0.025873 seconds, solution distance = 1.936e-01
# Finished cycle # 000023 in  0.028080 seconds, solution distance = 1.754e-01
# Finished cycle # 000024 in  0.026504 seconds, solution distance = 1.596e-01
# Finished cycle # 000025 in  0.026184 seconds, solution distance = 1.456e-01
# Finished cycle # 000026 in  0.027347 seconds, solution distance = 1.333e-01
# Finished cycle # 000027 in  0.031808 seconds, solution distance = 1.224e-01
# Finished cycle # 000028 in  0.024706 seconds, solution distance = 1.126e-01
# Finished cycle # 000029 in  0.025502 seconds, solution distance = 1.039e-01
# Finished cycle # 000030 in  0.028194 seconds, solution distance = 9.607e-02
# Finished cycle # 000031 in  0.028523 seconds, solution distance = 8.901e-02
# Finished cycle # 000032 in  0.025416 seconds, solution distance = 8.261e-02
# Finished cycle # 000033 in  0.024965 seconds, solution distance = 7.682e-02
# Finished cycle # 000034 in  0.025646 seconds, solution distance = 7.154e-02
# Finished cycle # 000035 in  0.026950 seconds, solution distance = 6.673e-02
# Finished cycle # 000036 in  0.026594 seconds, solution distance = 6.232e-02
# Finished cycle # 000037 in  0.029768 seconds, solution distance = 5.829e-02
# Finished cycle # 000038 in  0.026556 seconds, solution distance = 5.458e-02
# Finished cycle # 000039 in  0.025329 seconds, solution distance = 5.117e-02
# Finished cycle # 000040 in  0.026857 seconds, solution distance = 4.802e-02
# Finished cycle # 000041 in  0.025537 seconds, solution distance = 4.511e-02
# Finished cycle # 000042 in  0.027784 seconds, solution distance = 4.242e-02
# Finished cycle # 000043 in  0.024334 seconds, solution distance = 3.992e-02
# Finished cycle # 000044 in  0.024926 seconds, solution distance = 3.760e-02
# Finished cycle # 000045 in  0.024457 seconds, solution distance = 3.545e-02
# Finished cycle # 000046 in  0.027541 seconds, solution distance = 3.344e-02
# Finished cycle # 000047 in  0.028045 seconds, solution distance = 3.157e-02
# Finished cycle # 000048 in  0.026620 seconds, solution distance = 2.982e-02
# Finished cycle # 000049 in  0.024998 seconds, solution distance = 2.819e-02
# Finished cycle # 000050 in  0.029341 seconds, solution distance = 2.666e-02
# Finished cycle # 000051 in  0.026244 seconds, solution distance = 2.523e-02
# Finished cycle # 000052 in  0.025610 seconds, solution distance = 2.388e-02
# Finished cycle # 000053 in  0.024876 seconds, solution distance = 2.262e-02
# Finished cycle # 000054 in  0.031223 seconds, solution distance = 2.144e-02
# Finished cycle # 000055 in  0.028113 seconds, solution distance = 2.033e-02
# Finished cycle # 000056 in  0.024722 seconds, solution distance = 1.928e-02
# Finished cycle # 000057 in  0.025076 seconds, solution distance = 1.829e-02
# Finished cycle # 000058 in  0.026447 seconds, solution distance = 1.736e-02
# Finished cycle # 000059 in  0.025499 seconds, solution distance = 1.648e-02
# Finished cycle # 000060 in  0.025938 seconds, solution distance = 1.566e-02
# Finished cycle # 000061 in  0.027025 seconds, solution distance = 1.488e-02
# Finished cycle # 000062 in  0.025778 seconds, solution distance = 1.414e-02
# Finished cycle # 000063 in  0.027009 seconds, solution distance = 1.344e-02
# Finished cycle # 000064 in  0.028035 seconds, solution distance = 1.278e-02
# Finished cycle # 000065 in  0.026982 seconds, solution distance = 1.216e-02
# Finished cycle # 000066 in  0.028340 seconds, solution distance = 1.156e-02
# Finished cycle # 000067 in  0.025515 seconds, solution distance = 1.100e-02
# Finished cycle # 000068 in  0.028451 seconds, solution distance = 1.047e-02
# Finished cycle # 000069 in  0.025383 seconds, solution distance = 9.970e-03
# Finished cycle # 000070 in  0.029085 seconds, solution distance = 9.492e-03
# Finished cycle # 000071 in  0.025225 seconds, solution distance = 9.039e-03
# Finished cycle # 000072 in  0.027060 seconds, solution distance = 8.609e-03
# Finished cycle # 000073 in  0.024742 seconds, solution distance = 8.200e-03
# Finished cycle # 000074 in  0.027686 seconds, solution distance = 7.812e-03
# Finished cycle # 000075 in  0.026197 seconds, solution distance = 7.444e-03
# Finished cycle # 000076 in  0.027890 seconds, solution distance = 7.094e-03
# Finished cycle # 000077 in  0.032979 seconds, solution distance = 6.760e-03
# Finished cycle # 000078 in  0.026601 seconds, solution distance = 6.444e-03
# Finished cycle # 000079 in  0.028023 seconds, solution distance = 6.142e-03
# Finished cycle # 000080 in  0.028088 seconds, solution distance = 5.856e-03
# Finished cycle # 000081 in  0.029151 seconds, solution distance = 5.583e-03
# Finished cycle # 000082 in  0.025773 seconds, solution distance = 5.323e-03
# Finished cycle # 000083 in  0.030943 seconds, solution distance = 5.076e-03
# Finished cycle # 000084 in  0.028398 seconds, solution distance = 4.840e-03
# Finished cycle # 000085 in  0.026291 seconds, solution distance = 4.616e-03
# Finished cycle # 000086 in  0.029194 seconds, solution distance = 4.402e-03
# Finished cycle # 000087 in  0.027304 seconds, solution distance = 4.198e-03
# Finished cycle # 000088 in  0.030623 seconds, solution distance = 4.004e-03
# Finished cycle # 000089 in  0.029901 seconds, solution distance = 3.819e-03
# Finished cycle # 000090 in  0.027543 seconds, solution distance = 3.643e-03
# Finished cycle # 000091 in  0.026321 seconds, solution distance = 3.475e-03
# Finished cycle # 000092 in  0.026871 seconds, solution distance = 3.315e-03
# Finished cycle # 000093 in  0.028468 seconds, solution distance = 3.162e-03
# Finished cycle # 000094 in  0.027479 seconds, solution distance = 3.016e-03
# Finished cycle # 000095 in  0.033035 seconds, solution distance = 2.877e-03
# Finished cycle # 000096 in  0.028789 seconds, solution distance = 2.744e-03
# Finished cycle # 000097 in  0.026952 seconds, solution distance = 2.618e-03
# Finished cycle # 000098 in  0.028063 seconds, solution distance = 2.497e-03
# Finished cycle # 000099 in  0.026375 seconds, solution distance = 2.381e-03
# Finished cycle # 000100 in  0.027359 seconds, solution distance = 2.271e-03
# Finished cycle # 000101 in  0.028284 seconds, solution distance = 2.166e-03
# Finished cycle # 000102 in  0.027798 seconds, solution distance = 2.066e-03
# Finished cycle # 000103 in  0.028169 seconds, solution distance = 1.971e-03
# Finished cycle # 000104 in  0.028418 seconds, solution distance = 1.879e-03
# Finished cycle # 000105 in  0.026034 seconds, solution distance = 1.792e-03
# Finished cycle # 000106 in  0.027657 seconds, solution distance = 1.709e-03
# Finished cycle # 000107 in  0.026990 seconds, solution distance = 1.629e-03
# Finished cycle # 000108 in  0.027153 seconds, solution distance = 1.554e-03
# Finished cycle # 000109 in  0.026453 seconds, solution distance = 1.481e-03
# Finished cycle # 000110 in  0.025272 seconds, solution distance = 1.412e-03
# Finished cycle # 000111 in  0.030271 seconds, solution distance = 1.346e-03
# Finished cycle # 000112 in  0.026368 seconds, solution distance = 1.283e-03
# Finished cycle # 000113 in  0.028480 seconds, solution distance = 1.223e-03
# Finished cycle # 000114 in  0.026461 seconds, solution distance = 1.165e-03
# Finished cycle # 000115 in  0.029052 seconds, solution distance = 1.110e-03
# Finished cycle # 000116 in  0.026292 seconds, solution distance = 1.058e-03
# Finished cycle # 000117 in  0.026408 seconds, solution distance = 1.008e-03
# Finished cycle # 000118 in  0.025974 seconds, solution distance = 9.598e-04
# Finished cycle # 000119 in  0.028080 seconds, solution distance = 9.141e-04
# Finished cycle # 000120 in  0.026488 seconds, solution distance = 8.705e-04
# Finished cycle # 000121 in  0.028205 seconds, solution distance = 8.288e-04
# Finished cycle # 000122 in  0.027121 seconds, solution distance = 7.890e-04
# Finished cycle # 000123 in  0.026667 seconds, solution distance = 7.510e-04
# Finished cycle # 000124 in  0.033569 seconds, solution distance = 7.147e-04
# Finished cycle # 000125 in  0.026527 seconds, solution distance = 6.801e-04
# Finished cycle # 000126 in  0.027965 seconds, solution distance = 6.470e-04
# Finished cycle # 000127 in  0.031284 seconds, solution distance = 6.154e-04
# Finished cycle # 000128 in  0.031057 seconds, solution distance = 5.852e-04
# Finished cycle # 000129 in  0.027229 seconds, solution distance = 5.564e-04
# Finished cycle # 000130 in  0.027704 seconds, solution distance = 5.288e-04
# Finished cycle # 000131 in  0.027885 seconds, solution distance = 5.025e-04
# Finished cycle # 000132 in  0.027146 seconds, solution distance = 4.774e-04
# Finished cycle # 000133 in  0.027630 seconds, solution distance = 4.535e-04
# Finished cycle # 000134 in  0.028219 seconds, solution distance = 4.306e-04
# Finished cycle # 000135 in  0.028186 seconds, solution distance = 4.088e-04
# Finished cycle # 000136 in  0.028495 seconds, solution distance = 3.879e-04
# Finished cycle # 000137 in  0.027193 seconds, solution distance = 3.680e-04
# Finished cycle # 000138 in  0.029517 seconds, solution distance = 3.490e-04
# Finished cycle # 000139 in  0.026617 seconds, solution distance = 3.309e-04
# Finished cycle # 000140 in  0.029403 seconds, solution distance = 3.136e-04
# Finished cycle # 000141 in  0.027398 seconds, solution distance = 2.971e-04
# Finished cycle # 000142 in  0.027434 seconds, solution distance = 2.813e-04
# Finished cycle # 000143 in  0.031570 seconds, solution distance = 2.662e-04
# Finished cycle # 000144 in  0.029565 seconds, solution distance = 2.519e-04
# Finished cycle # 000145 in  0.026317 seconds, solution distance = 2.382e-04
# Finished cycle # 000146 in  0.026040 seconds, solution distance = 2.251e-04
# Finished cycle # 000147 in  0.029825 seconds, solution distance = 2.127e-04
# Finished cycle # 000148 in  0.031367 seconds, solution distance = 2.008e-04
# Finished cycle # 000149 in  0.031322 seconds, solution distance = 1.894e-04
# Finished cycle # 000150 in  0.029295 seconds, solution distance = 1.786e-04
# Finished cycle # 000151 in  0.026482 seconds, solution distance = 1.683e-04
# Finished cycle # 000152 in  0.029346 seconds, solution distance = 1.585e-04
# Finished cycle # 000153 in  0.025605 seconds, solution distance = 1.491e-04
# Finished cycle # 000154 in  0.027460 seconds, solution distance = 1.402e-04
# Finished cycle # 000155 in  0.027039 seconds, solution distance = 1.316e-04
# Finished cycle # 000156 in  0.027400 seconds, solution distance = 1.235e-04
# Finished cycle # 000157 in  0.029468 seconds, solution distance = 1.158e-04
# Finished cycle # 000158 in  0.027898 seconds, solution distance = 1.084e-04
# Finished cycle # 000159 in  0.032058 seconds, solution distance = 1.014e-04
# Finished cycle # 000160 in  0.027402 seconds, solution distance = 9.470e-05
# Finished cycle # 000161 in  0.030280 seconds, solution distance = 8.833e-05
# Finished cycle # 000162 in  0.025723 seconds, solution distance = 8.226e-05
# Finished cycle # 000163 in  0.026806 seconds, solution distance = 7.649e-05
# Finished cycle # 000164 in  0.027872 seconds, solution distance = 7.121e-05
# Finished cycle # 000165 in  0.028360 seconds, solution distance = 6.629e-05
# Finished cycle # 000166 in  0.030553 seconds, solution distance = 6.161e-05
# Finished cycle # 000167 in  0.026942 seconds, solution distance = 5.738e-05
# Finished cycle # 000168 in  0.028044 seconds, solution distance = 5.338e-05
# Finished cycle # 000169 in  0.025817 seconds, solution distance = 4.961e-05
# Finished cycle # 000170 in  0.026821 seconds, solution distance = 4.619e-05
# Finished cycle # 000171 in  0.028363 seconds, solution distance = 4.293e-05
# Finished cycle # 000172 in  0.030967 seconds, solution distance = 3.992e-05
# Finished cycle # 000173 in  0.026857 seconds, solution distance = 3.713e-05
# Finished cycle # 000174 in  0.029394 seconds, solution distance = 3.448e-05
# Finished cycle # 000175 in  0.028344 seconds, solution distance = 3.208e-05
# Finished cycle # 000176 in  0.027022 seconds, solution distance = 2.981e-05
# Finished cycle # 000177 in  0.030368 seconds, solution distance = 2.770e-05
# Finished cycle # 000178 in  0.027110 seconds, solution distance = 2.575e-05
# Finished cycle # 000179 in  0.029012 seconds, solution distance = 2.390e-05
# Finished cycle # 000180 in  0.026075 seconds, solution distance = 2.222e-05
# Finished cycle # 000181 in  0.027362 seconds, solution distance = 2.062e-05
# Finished cycle # 000182 in  0.027577 seconds, solution distance = 1.916e-05
# Finished cycle # 000183 in  0.027516 seconds, solution distance = 1.779e-05
# Finished cycle # 000184 in  0.028549 seconds, solution distance = 1.652e-05
# Finished cycle # 000185 in  0.026630 seconds, solution distance = 1.533e-05
# Finished cycle # 000186 in  0.028410 seconds, solution distance = 1.423e-05
# Finished cycle # 000187 in  0.027214 seconds, solution distance = 1.320e-05
# Finished cycle # 000188 in  0.027395 seconds, solution distance = 1.225e-05
# Finished cycle # 000189 in  0.026212 seconds, solution distance = 1.136e-05
# Finished cycle # 000190 in  0.029785 seconds, solution distance = 1.054e-05
# Finished cycle # 000191 in  0.029567 seconds, solution distance = 9.775e-06
# Finished cycle # 000192 in  0.027571 seconds, solution distance = 9.064e-06
# Finished cycle # 000193 in  0.029487 seconds, solution distance = 9.578e-06
# Finished cycle # 000194 in  0.025773 seconds, solution distance = 1.066e-05
# Finished cycle # 000195 in  0.027822 seconds, solution distance = 1.168e-05
# Finished cycle # 000196 in  0.024926 seconds, solution distance = 1.264e-05
# Finished cycle # 000197 in  0.028389 seconds, solution distance = 1.354e-05
# Finished cycle # 000198 in  0.029626 seconds, solution distance = 1.438e-05
# Finished cycle # 000199 in  0.026573 seconds, solution distance = 1.517e-05
# Finished cycle # 000200 in  0.025456 seconds, solution distance = 1.591e-05
# Finished cycle # 000201 in  0.026268 seconds, solution distance = 1.659e-05
# Finished cycle # 000202 in  0.026680 seconds, solution distance = 1.723e-05
# Finished cycle # 000203 in  0.025911 seconds, solution distance = 1.783e-05
# Finished cycle # 000204 in  0.027938 seconds, solution distance = 1.839e-05
# Finished cycle # 000205 in  0.024738 seconds, solution distance = 1.890e-05
# Finished cycle # 000206 in  0.026066 seconds, solution distance = 1.938e-05
# Finished cycle # 000207 in  0.025984 seconds, solution distance = 1.982e-05
# Finished cycle # 000208 in  0.026348 seconds, solution distance = 2.022e-05
# Finished cycle # 000209 in  0.025933 seconds, solution distance = 2.059e-05
# Finished cycle # 000210 in  0.027391 seconds, solution distance = 2.093e-05
# Finished cycle # 000211 in  0.024895 seconds, solution distance = 2.125e-05
# Finished cycle # 000212 in  0.027987 seconds, solution distance = 2.153e-05
# Finished cycle # 000213 in  0.026331 seconds, solution distance = 2.178e-05
# Finished cycle # 000214 in  0.027954 seconds, solution distance = 2.202e-05
# Finished cycle # 000215 in  0.026756 seconds, solution distance = 2.222e-05
# Finished cycle # 000216 in  0.027383 seconds, solution distance = 2.241e-05
# Finished cycle # 000217 in  0.025485 seconds, solution distance = 2.257e-05
# Finished cycle # 000218 in  0.025063 seconds, solution distance = 2.271e-05
# Finished cycle # 000219 in  0.028444 seconds, solution distance = 2.283e-05
# Finished cycle # 000220 in  0.028414 seconds, solution distance = 2.293e-05
# Finished cycle # 000221 in  0.027175 seconds, solution distance = 2.302e-05
# Finished cycle # 000222 in  0.026433 seconds, solution distance = 2.309e-05
# Finished cycle # 000223 in  0.026367 seconds, solution distance = 2.314e-05
# Finished cycle # 000224 in  0.025290 seconds, solution distance = 2.318e-05
# Finished cycle # 000225 in  0.025848 seconds, solution distance = 2.321e-05
# Finished cycle # 000226 in  0.024294 seconds, solution distance = 2.322e-05
# Finished cycle # 000227 in  0.025458 seconds, solution distance = 2.322e-05
# Finished cycle # 000228 in  0.024784 seconds, solution distance = 2.320e-05
# Finished cycle # 000229 in  0.026632 seconds, solution distance = 2.318e-05
# Finished cycle # 000230 in  0.029065 seconds, solution distance = 2.314e-05
# Finished cycle # 000231 in  0.025494 seconds, solution distance = 2.310e-05
# Finished cycle # 000232 in  0.027034 seconds, solution distance = 2.304e-05
# Finished cycle # 000233 in  0.025013 seconds, solution distance = 2.298e-05
# Finished cycle # 000234 in  0.025461 seconds, solution distance = 2.291e-05
# Finished cycle # 000235 in  0.027212 seconds, solution distance = 2.283e-05
# Finished cycle # 000236 in  0.026543 seconds, solution distance = 2.274e-05
# Finished cycle # 000237 in  0.029325 seconds, solution distance = 2.265e-05
# Finished cycle # 000238 in  0.032626 seconds, solution distance = 2.255e-05
# Finished cycle # 000239 in  0.029814 seconds, solution distance = 2.245e-05
# Finished cycle # 000240 in  0.026055 seconds, solution distance = 2.233e-05
# Finished cycle # 000241 in  0.027044 seconds, solution distance = 2.222e-05
# Finished cycle # 000242 in  0.026267 seconds, solution distance = 2.210e-05
# Finished cycle # 000243 in  0.028036 seconds, solution distance = 2.197e-05
# Finished cycle # 000244 in  0.028951 seconds, solution distance = 2.184e-05
# Finished cycle # 000245 in  0.025810 seconds, solution distance = 2.171e-05
# Finished cycle # 000246 in  0.027375 seconds, solution distance = 2.157e-05
# Finished cycle # 000247 in  0.025482 seconds, solution distance = 2.143e-05
# Finished cycle # 000248 in  0.025301 seconds, solution distance = 2.128e-05
# Finished cycle # 000249 in  0.025242 seconds, solution distance = 2.114e-05
# Finished cycle # 000250 in  0.025388 seconds, solution distance = 2.099e-05
# Finished cycle # 000251 in  0.025147 seconds, solution distance = 2.083e-05
# Finished cycle # 000252 in  0.025080 seconds, solution distance = 2.068e-05
# Finished cycle # 000253 in  0.025214 seconds, solution distance = 2.052e-05
# Finished cycle # 000254 in  0.027812 seconds, solution distance = 2.037e-05
# Finished cycle # 000255 in  0.029432 seconds, solution distance = 2.021e-05
# Finished cycle # 000256 in  0.025408 seconds, solution distance = 2.005e-05
# Finished cycle # 000257 in  0.026703 seconds, solution distance = 1.989e-05
# Finished cycle # 000258 in  0.027407 seconds, solution distance = 1.972e-05
# Finished cycle # 000259 in  0.030785 seconds, solution distance = 1.956e-05
# Finished cycle # 000260 in  0.025566 seconds, solution distance = 1.939e-05
# Finished cycle # 000261 in  0.026575 seconds, solution distance = 1.923e-05
# Finished cycle # 000262 in  0.029232 seconds, solution distance = 1.906e-05
# Finished cycle # 000263 in  0.025448 seconds, solution distance = 1.890e-05
# Finished cycle # 000264 in  0.026361 seconds, solution distance = 1.873e-05
# Finished cycle # 000265 in  0.026808 seconds, solution distance = 1.856e-05
# Finished cycle # 000266 in  0.027701 seconds, solution distance = 1.840e-05
# Finished cycle # 000267 in  0.025657 seconds, solution distance = 1.823e-05
# Finished cycle # 000268 in  0.025611 seconds, solution distance = 1.806e-05
# Finished cycle # 000269 in  0.026628 seconds, solution distance = 1.790e-05
# Finished cycle # 000270 in  0.026750 seconds, solution distance = 1.773e-05
# Finished cycle # 000271 in  0.029232 seconds, solution distance = 1.757e-05
# Finished cycle # 000272 in  0.026630 seconds, solution distance = 1.740e-05
# Finished cycle # 000273 in  0.026826 seconds, solution distance = 1.724e-05
# Finished cycle # 000274 in  0.024756 seconds, solution distance = 1.707e-05
# Finished cycle # 000275 in  0.027734 seconds, solution distance = 1.691e-05
# Finished cycle # 000276 in  0.024760 seconds, solution distance = 1.674e-05
# Finished cycle # 000277 in  0.025671 seconds, solution distance = 1.658e-05
# Finished cycle # 000278 in  0.031006 seconds, solution distance = 1.642e-05
# Finished cycle # 000279 in  0.025624 seconds, solution distance = 1.626e-05
# Finished cycle # 000280 in  0.026519 seconds, solution distance = 1.610e-05
# Finished cycle # 000281 in  0.026153 seconds, solution distance = 1.594e-05
# Finished cycle # 000282 in  0.025134 seconds, solution distance = 1.578e-05
# Finished cycle # 000283 in  0.024808 seconds, solution distance = 1.563e-05
# Finished cycle # 000284 in  0.028958 seconds, solution distance = 1.547e-05
# Finished cycle # 000285 in  0.027153 seconds, solution distance = 1.531e-05
# Finished cycle # 000286 in  0.026351 seconds, solution distance = 1.516e-05
# Finished cycle # 000287 in  0.027037 seconds, solution distance = 1.501e-05
# Finished cycle # 000288 in  0.027172 seconds, solution distance = 1.485e-05
# Finished cycle # 000289 in  0.027212 seconds, solution distance = 1.470e-05
# Finished cycle # 000290 in  0.028231 seconds, solution distance = 1.455e-05
# Finished cycle # 000291 in  0.032319 seconds, solution distance = 1.441e-05
# Finished cycle # 000292 in  0.028724 seconds, solution distance = 1.426e-05
# Finished cycle # 000293 in  0.027869 seconds, solution distance = 1.411e-05
# Finished cycle # 000294 in  0.031901 seconds, solution distance = 1.397e-05
# Finished cycle # 000295 in  0.027332 seconds, solution distance = 1.382e-05
# Finished cycle # 000296 in  0.030138 seconds, solution distance = 1.368e-05
# Finished cycle # 000297 in  0.027088 seconds, solution distance = 1.354e-05
# Finished cycle # 000298 in  0.027396 seconds, solution distance = 1.340e-05
# Finished cycle # 000299 in  0.028222 seconds, solution distance = 1.326e-05
# Finished cycle # 000300 in  0.026417 seconds, solution distance = 1.312e-05
# Finished cycle # 000301 in  0.027029 seconds, solution distance = 1.298e-05
# Finished cycle # 000302 in  0.027821 seconds, solution distance = 1.285e-05
# Finished cycle # 000303 in  0.027453 seconds, solution distance = 1.271e-05
# Finished cycle # 000304 in  0.025536 seconds, solution distance = 1.258e-05
# Finished cycle # 000305 in  0.025680 seconds, solution distance = 1.245e-05
# Finished cycle # 000306 in  0.028726 seconds, solution distance = 1.232e-05
# Finished cycle # 000307 in  0.028162 seconds, solution distance = 1.219e-05
# Finished cycle # 000308 in  0.030326 seconds, solution distance = 1.206e-05
# Finished cycle # 000309 in  0.024712 seconds, solution distance = 1.193e-05
# Finished cycle # 000310 in  0.033441 seconds, solution distance = 1.181e-05
# Finished cycle # 000311 in  0.026425 seconds, solution distance = 1.168e-05
# Finished cycle # 000312 in  0.030839 seconds, solution distance = 1.156e-05
# Finished cycle # 000313 in  0.029822 seconds, solution distance = 1.144e-05
# Finished cycle # 000314 in  0.027461 seconds, solution distance = 1.132e-05
# Finished cycle # 000315 in  0.027791 seconds, solution distance = 1.120e-05
# Finished cycle # 000316 in  0.026563 seconds, solution distance = 1.108e-05
# Finished cycle # 000317 in  0.025226 seconds, solution distance = 1.096e-05
# Finished cycle # 000318 in  0.025463 seconds, solution distance = 1.085e-05
# Finished cycle # 000319 in  0.025311 seconds, solution distance = 1.073e-05
# Finished cycle # 000320 in  0.025231 seconds, solution distance = 1.062e-05
# Finished cycle # 000321 in  0.028613 seconds, solution distance = 1.051e-05
# Finished cycle # 000322 in  0.031012 seconds, solution distance = 1.040e-05
# Finished cycle # 000323 in  0.026930 seconds, solution distance = 1.029e-05
# Finished cycle # 000324 in  0.026145 seconds, solution distance = 1.018e-05
# Finished cycle # 000325 in  0.031407 seconds, solution distance = 1.007e-05
# Finished cycle # 000326 in  0.029255 seconds, solution distance = 9.963e-06
# Finished cycle # 000327 in  0.027520 seconds, solution distance = 9.857e-06
# Finished cycle # 000328 in  0.028664 seconds, solution distance = 9.753e-06
# Finished cycle # 000329 in  0.030636 seconds, solution distance = 9.649e-06
# Finished cycle # 000330 in  0.027387 seconds, solution distance = 9.547e-06
# Finished cycle # 000331 in  0.028740 seconds, solution distance = 9.446e-06
# Finished cycle # 000332 in  0.035501 seconds, solution distance = 9.346e-06
# Finished cycle # 000333 in  0.034594 seconds, solution distance = 9.247e-06
# Finished cycle # 000334 in  0.028894 seconds, solution distance = 9.149e-06
# Finished cycle # 000335 in  0.030441 seconds, solution distance = 9.052e-06
# Finished cycle # 000336 in  0.035767 seconds, solution distance = 8.957e-06
# Finished cycle # 000337 in  0.034258 seconds, solution distance = 8.862e-06
# Finished cycle # 000338 in  0.030271 seconds, solution distance = 8.768e-06
# Finished cycle # 000339 in  0.029932 seconds, solution distance = 8.675e-06
# Finished cycle # 000340 in  0.031223 seconds, solution distance = 8.584e-06
# Finished cycle # 000341 in  0.036652 seconds, solution distance = 8.493e-06
# Finished cycle # 000342 in  0.027937 seconds, solution distance = 8.403e-06
# Finished cycle # 000343 in  0.026999 seconds, solution distance = 8.314e-06
# Finished cycle # 000344 in  0.029000 seconds, solution distance = 8.227e-06
# Finished cycle # 000345 in  0.027879 seconds, solution distance = 8.140e-06
# Finished cycle # 000346 in  0.028568 seconds, solution distance = 8.054e-06
# Finished cycle # 000347 in  0.034312 seconds, solution distance = 7.969e-06
# Finished cycle # 000348 in  0.028645 seconds, solution distance = 7.885e-06
# Finished cycle # 000349 in  0.029718 seconds, solution distance = 7.802e-06
# Finished cycle # 000350 in  0.027880 seconds, solution distance = 7.719e-06
# Finished cycle # 000351 in  0.027934 seconds, solution distance = 7.638e-06
# Finished cycle # 000352 in  0.030608 seconds, solution distance = 7.558e-06
# Finished cycle # 000353 in  0.033399 seconds, solution distance = 7.478e-06
# Finished cycle # 000354 in  0.033433 seconds, solution distance = 7.400e-06
# Finished cycle # 000355 in  0.032255 seconds, solution distance = 7.322e-06
# Finished cycle # 000356 in  0.032152 seconds, solution distance = 7.245e-06
# Finished cycle # 000357 in  0.028742 seconds, solution distance = 7.169e-06
# Finished cycle # 000358 in  0.027987 seconds, solution distance = 7.093e-06
# Finished cycle # 000359 in  0.028087 seconds, solution distance = 7.019e-06
# Finished cycle # 000360 in  0.033743 seconds, solution distance = 6.945e-06
# Finished cycle # 000361 in  0.033044 seconds, solution distance = 6.872e-06
# Finished cycle # 000362 in  0.030078 seconds, solution distance = 6.800e-06
# Finished cycle # 000363 in  0.028837 seconds, solution distance = 6.729e-06
# Finished cycle # 000364 in  0.029895 seconds, solution distance = 6.659e-06
# Finished cycle # 000365 in  0.028910 seconds, solution distance = 6.589e-06
# Finished cycle # 000366 in  0.028293 seconds, solution distance = 6.520e-06
# Finished cycle # 000367 in  0.028113 seconds, solution distance = 6.452e-06
# Finished cycle # 000368 in  0.028799 seconds, solution distance = 6.385e-06
# Finished cycle # 000369 in  0.030848 seconds, solution distance = 6.318e-06
# Finished cycle # 000370 in  0.029802 seconds, solution distance = 6.252e-06
# Finished cycle # 000371 in  0.030188 seconds, solution distance = 6.187e-06
# Finished cycle # 000372 in  0.028453 seconds, solution distance = 6.122e-06
# Finished cycle # 000373 in  0.029954 seconds, solution distance = 6.058e-06
# Finished cycle # 000374 in  0.030366 seconds, solution distance = 5.995e-06
# Finished cycle # 000375 in  0.028628 seconds, solution distance = 5.933e-06
# Finished cycle # 000376 in  0.029937 seconds, solution distance = 5.871e-06
# Finished cycle # 000377 in  0.029347 seconds, solution distance = 5.810e-06
# Finished cycle # 000378 in  0.034598 seconds, solution distance = 5.750e-06
# Finished cycle # 000379 in  0.038467 seconds, solution distance = 5.690e-06
# Finished cycle # 000380 in  0.034303 seconds, solution distance = 5.631e-06
# Finished cycle # 000381 in  0.028871 seconds, solution distance = 5.573e-06
# Finished cycle # 000382 in  0.028355 seconds, solution distance = 5.515e-06
# Finished cycle # 000383 in  0.031144 seconds, solution distance = 5.458e-06
# Finished cycle # 000384 in  0.028994 seconds, solution distance = 5.401e-06
# Finished cycle # 000385 in  0.031020 seconds, solution distance = 5.345e-06
# Finished cycle # 000386 in  0.034228 seconds, solution distance = 5.290e-06
# Finished cycle # 000387 in  0.029203 seconds, solution distance = 5.235e-06
# Finished cycle # 000388 in  0.028953 seconds, solution distance = 5.181e-06
# Finished cycle # 000389 in  0.029211 seconds, solution distance = 5.128e-06
# Finished cycle # 000390 in  0.031229 seconds, solution distance = 5.075e-06
# Finished cycle # 000391 in  0.032834 seconds, solution distance = 5.022e-06
# Finished cycle # 000392 in  0.030399 seconds, solution distance = 4.970e-06
# Finished cycle # 000393 in  0.030922 seconds, solution distance = 4.919e-06
# Finished cycle # 000394 in  0.029588 seconds, solution distance = 4.869e-06
# Finished cycle # 000395 in  0.029671 seconds, solution distance = 4.818e-06
# Finished cycle # 000396 in  0.029991 seconds, solution distance = 4.769e-06
# Finished cycle # 000397 in  0.032203 seconds, solution distance = 4.720e-06
# Finished cycle # 000398 in  0.032154 seconds, solution distance = 4.671e-06
# Finished cycle # 000399 in  0.029146 seconds, solution distance = 4.623e-06
# Finished cycle # 000400 in  0.032209 seconds, solution distance = 4.576e-06
# Finished cycle # 000401 in  0.035183 seconds, solution distance = 4.529e-06
# Finished cycle # 000402 in  0.031850 seconds, solution distance = 4.482e-06
# Finished cycle # 000403 in  0.031473 seconds, solution distance = 4.436e-06
# Finished cycle # 000404 in  0.030679 seconds, solution distance = 4.391e-06
# Finished cycle # 000405 in  0.031285 seconds, solution distance = 4.346e-06
# Finished cycle # 000406 in  0.031567 seconds, solution distance = 4.301e-06
# Finished cycle # 000407 in  0.035423 seconds, solution distance = 4.257e-06
# Finished cycle # 000408 in  0.031141 seconds, solution distance = 4.214e-06
# Finished cycle # 000409 in  0.032065 seconds, solution distance = 4.171e-06
# Finished cycle # 000410 in  0.035479 seconds, solution distance = 4.128e-06
# Finished cycle # 000411 in  0.036663 seconds, solution distance = 4.086e-06
# Finished cycle # 000412 in  0.033699 seconds, solution distance = 4.044e-06
# Finished cycle # 000413 in  0.033507 seconds, solution distance = 4.003e-06
# Finished cycle # 000414 in  0.029683 seconds, solution distance = 3.962e-06
# Finished cycle # 000415 in  0.030867 seconds, solution distance = 3.922e-06
# Finished cycle # 000416 in  0.029988 seconds, solution distance = 3.882e-06
# Finished cycle # 000417 in  0.034949 seconds, solution distance = 3.842e-06
# Finished cycle # 000418 in  0.035465 seconds, solution distance = 3.803e-06
# Finished cycle # 000419 in  0.030570 seconds, solution distance = 3.765e-06
# Finished cycle # 000420 in  0.032151 seconds, solution distance = 3.726e-06
# Finished cycle # 000421 in  0.031278 seconds, solution distance = 3.689e-06
# Finished cycle # 000422 in  0.030430 seconds, solution distance = 3.651e-06
# Finished cycle # 000423 in  0.032575 seconds, solution distance = 3.614e-06
# Finished cycle # 000424 in  0.031701 seconds, solution distance = 3.577e-06
# Finished cycle # 000425 in  0.033726 seconds, solution distance = 3.541e-06
# Finished cycle # 000426 in  0.031661 seconds, solution distance = 3.505e-06
# Finished cycle # 000427 in  0.030451 seconds, solution distance = 3.470e-06
# Finished cycle # 000428 in  0.034939 seconds, solution distance = 3.435e-06
# Finished cycle # 000429 in  0.032188 seconds, solution distance = 3.400e-06
# Finished cycle # 000430 in  0.031641 seconds, solution distance = 3.365e-06
# Finished cycle # 000431 in  0.031076 seconds, solution distance = 3.331e-06
# Finished cycle # 000432 in  0.041801 seconds, solution distance = 3.298e-06
# Finished cycle # 000433 in  0.034305 seconds, solution distance = 3.264e-06
# Finished cycle # 000434 in  0.032297 seconds, solution distance = 3.231e-06
# Finished cycle # 000435 in  0.031196 seconds, solution distance = 3.199e-06
# Finished cycle # 000436 in  0.030316 seconds, solution distance = 3.166e-06
# Finished cycle # 000437 in  0.029653 seconds, solution distance = 3.135e-06
# Finished cycle # 000438 in  0.029887 seconds, solution distance = 3.103e-06
# Finished cycle # 000439 in  0.035417 seconds, solution distance = 3.072e-06
# Finished cycle # 000440 in  0.031809 seconds, solution distance = 3.041e-06
# Finished cycle # 000441 in  0.032363 seconds, solution distance = 3.010e-06
# Finished cycle # 000442 in  0.029420 seconds, solution distance = 2.980e-06
# Finished cycle # 000443 in  0.031677 seconds, solution distance = 2.950e-06
# Finished cycle # 000444 in  0.028611 seconds, solution distance = 2.920e-06
# Finished cycle # 000445 in  0.027850 seconds, solution distance = 2.891e-06
# Finished cycle # 000446 in  0.029802 seconds, solution distance = 2.862e-06
# Finished cycle # 000447 in  0.028474 seconds, solution distance = 2.833e-06
# Finished cycle # 000448 in  0.031128 seconds, solution distance = 2.805e-06
# Finished cycle # 000449 in  0.030184 seconds, solution distance = 2.776e-06
# Finished cycle # 000450 in  0.029764 seconds, solution distance = 2.749e-06
# Finished cycle # 000451 in  0.029688 seconds, solution distance = 2.721e-06
# Finished cycle # 000452 in  0.031625 seconds, solution distance = 2.694e-06
# Finished cycle # 000453 in  0.030497 seconds, solution distance = 2.667e-06
# Finished cycle # 000454 in  0.033045 seconds, solution distance = 2.640e-06
# Finished cycle # 000455 in  0.028390 seconds, solution distance = 2.614e-06
# Finished cycle # 000456 in  0.029441 seconds, solution distance = 2.587e-06
# Finished cycle # 000457 in  0.027997 seconds, solution distance = 2.561e-06
# Finished cycle # 000458 in  0.028037 seconds, solution distance = 2.536e-06
# Finished cycle # 000459 in  0.027387 seconds, solution distance = 2.511e-06
# Finished cycle # 000460 in  0.028224 seconds, solution distance = 2.485e-06
# Finished cycle # 000461 in  0.028023 seconds, solution distance = 2.461e-06
# Finished cycle # 000462 in  0.027543 seconds, solution distance = 2.436e-06
# Finished cycle # 000463 in  0.027965 seconds, solution distance = 2.412e-06
# Finished cycle # 000464 in  0.027040 seconds, solution distance = 2.388e-06
# Finished cycle # 000465 in  0.041109 seconds, solution distance = 2.364e-06
# Finished cycle # 000466 in  0.036755 seconds, solution distance = 2.340e-06
# Finished cycle # 000467 in  0.032802 seconds, solution distance = 2.317e-06
# Finished cycle # 000468 in  0.030668 seconds, solution distance = 2.294e-06
# Finished cycle # 000469 in  0.031690 seconds, solution distance = 2.271e-06
# Finished cycle # 000470 in  0.034473 seconds, solution distance = 2.248e-06
# Finished cycle # 000471 in  0.035735 seconds, solution distance = 2.226e-06
# Finished cycle # 000472 in  0.030963 seconds, solution distance = 2.204e-06
# Finished cycle # 000473 in  0.029704 seconds, solution distance = 2.182e-06
# Finished cycle # 000474 in  0.029699 seconds, solution distance = 2.160e-06
# Finished cycle # 000475 in  0.030245 seconds, solution distance = 2.139e-06
# Finished cycle # 000476 in  0.027707 seconds, solution distance = 2.117e-06
# Finished cycle # 000477 in  0.027509 seconds, solution distance = 2.096e-06
# Finished cycle # 000478 in  0.029262 seconds, solution distance = 2.075e-06
# Finished cycle # 000479 in  0.047569 seconds, solution distance = 2.055e-06
# Finished cycle # 000480 in  0.032562 seconds, solution distance = 2.034e-06
# Finished cycle # 000481 in  0.032243 seconds, solution distance = 2.014e-06
# Finished cycle # 000482 in  0.031567 seconds, solution distance = 1.994e-06
# Finished cycle # 000483 in  0.027617 seconds, solution distance = 1.974e-06
# Finished cycle # 000484 in  0.030185 seconds, solution distance = 1.955e-06
# Finished cycle # 000485 in  0.028407 seconds, solution distance = 1.936e-06
# Finished cycle # 000486 in  0.029054 seconds, solution distance = 1.916e-06
# Finished cycle # 000487 in  0.027624 seconds, solution distance = 1.897e-06
# Finished cycle # 000488 in  0.028862 seconds, solution distance = 1.879e-06
# Finished cycle # 000489 in  0.027797 seconds, solution distance = 1.860e-06
# Finished cycle # 000490 in  0.032897 seconds, solution distance = 1.842e-06
# Finished cycle # 000491 in  0.028702 seconds, solution distance = 1.823e-06
# Finished cycle # 000492 in  0.028315 seconds, solution distance = 1.805e-06
# Finished cycle # 000493 in  0.028365 seconds, solution distance = 1.787e-06
# Finished cycle # 000494 in  0.030005 seconds, solution distance = 1.770e-06
# Finished cycle # 000495 in  0.028837 seconds, solution distance = 1.752e-06
# Finished cycle # 000496 in  0.028106 seconds, solution distance = 1.735e-06
# Finished cycle # 000497 in  0.028754 seconds, solution distance = 1.718e-06
# Finished cycle # 000498 in  0.029665 seconds, solution distance = 1.701e-06
# Finished cycle # 000499 in  0.037240 seconds, solution distance = 1.684e-06
# Finished cycle # 000500 in  0.033367 seconds, solution distance = 1.667e-06
# Finished cycle # 000501 in  0.029351 seconds, solution distance = 1.651e-06
# Finished cycle # 000502 in  0.033549 seconds, solution distance = 1.635e-06
# Finished cycle # 000503 in  0.029312 seconds, solution distance = 1.618e-06
# Finished cycle # 000504 in  0.027830 seconds, solution distance = 1.602e-06
# Finished cycle # 000505 in  0.028358 seconds, solution distance = 1.587e-06
# Finished cycle # 000506 in  0.026776 seconds, solution distance = 1.571e-06
# Finished cycle # 000507 in  0.026369 seconds, solution distance = 1.556e-06
# Finished cycle # 000508 in  0.029745 seconds, solution distance = 1.540e-06
# Finished cycle # 000509 in  0.030739 seconds, solution distance = 1.525e-06
# Finished cycle # 000510 in  0.029077 seconds, solution distance = 1.510e-06
# Finished cycle # 000511 in  0.026735 seconds, solution distance = 1.495e-06
# Finished cycle # 000512 in  0.027976 seconds, solution distance = 1.480e-06
# Finished cycle # 000513 in  0.031873 seconds, solution distance = 1.466e-06
# Finished cycle # 000514 in  0.026643 seconds, solution distance = 1.451e-06
# Finished cycle # 000515 in  0.027354 seconds, solution distance = 1.437e-06
# Finished cycle # 000516 in  0.028880 seconds, solution distance = 1.423e-06
# Finished cycle # 000517 in  0.026961 seconds, solution distance = 1.409e-06
# Finished cycle # 000518 in  0.035609 seconds, solution distance = 1.395e-06
# Finished cycle # 000519 in  0.034046 seconds, solution distance = 1.381e-06
# Finished cycle # 000520 in  0.028286 seconds, solution distance = 1.368e-06
# Finished cycle # 000521 in  0.029057 seconds, solution distance = 1.354e-06
# Finished cycle # 000522 in  0.029287 seconds, solution distance = 1.341e-06
# Finished cycle # 000523 in  0.028042 seconds, solution distance = 1.328e-06
# Finished cycle # 000524 in  0.029292 seconds, solution distance = 1.315e-06
# Finished cycle # 000525 in  0.033989 seconds, solution distance = 1.302e-06
# Finished cycle # 000526 in  0.030220 seconds, solution distance = 1.289e-06
# Finished cycle # 000527 in  0.028930 seconds, solution distance = 1.277e-06
# Finished cycle # 000528 in  0.028123 seconds, solution distance = 1.264e-06
# Finished cycle # 000529 in  0.027971 seconds, solution distance = 1.252e-06
# Finished cycle # 000530 in  0.027611 seconds, solution distance = 1.239e-06
# Finished cycle # 000531 in  0.036242 seconds, solution distance = 1.227e-06
# Finished cycle # 000532 in  0.034658 seconds, solution distance = 1.215e-06
# Finished cycle # 000533 in  0.028854 seconds, solution distance = 1.203e-06
# Finished cycle # 000534 in  0.028826 seconds, solution distance = 1.191e-06
# Finished cycle # 000535 in  0.027400 seconds, solution distance = 1.180e-06
# Finished cycle # 000536 in  0.031950 seconds, solution distance = 1.168e-06
# Finished cycle # 000537 in  0.029082 seconds, solution distance = 1.157e-06
# Finished cycle # 000538 in  0.028144 seconds, solution distance = 1.145e-06
# Finished cycle # 000539 in  0.032879 seconds, solution distance = 1.134e-06
# Finished cycle # 000540 in  0.027738 seconds, solution distance = 1.123e-06
# Finished cycle # 000541 in  0.028593 seconds, solution distance = 1.112e-06
# Finished cycle # 000542 in  0.030852 seconds, solution distance = 1.101e-06
# Finished cycle # 000543 in  0.032475 seconds, solution distance = 1.090e-06
# Finished cycle # 000544 in  0.031783 seconds, solution distance = 1.080e-06
# Finished cycle # 000545 in  0.028366 seconds, solution distance = 1.069e-06
# Finished cycle # 000546 in  0.030061 seconds, solution distance = 1.059e-06
# Finished cycle # 000547 in  0.029721 seconds, solution distance = 1.048e-06
# Finished cycle # 000548 in  0.032487 seconds, solution distance = 1.038e-06
# Finished cycle # 000549 in  0.035419 seconds, solution distance = 1.028e-06
# Finished cycle # 000550 in  0.031619 seconds, solution distance = 1.018e-06
# Finished cycle # 000551 in  0.031968 seconds, solution distance = 1.008e-06
# Finished cycle # 000552 in  0.031810 seconds, solution distance = 9.981e-07
# Finished cycle # 000553 in  0.029384 seconds, solution distance = 9.884e-07
# Finished cycle # 000554 in  0.031664 seconds, solution distance = 9.787e-07
# Finished cycle # 000555 in  0.034820 seconds, solution distance = 9.692e-07
# Finished cycle # 000556 in  0.029718 seconds, solution distance = 9.597e-07
# Finished cycle # 000557 in  0.030726 seconds, solution distance = 9.503e-07
# Finished cycle # 000558 in  0.032164 seconds, solution distance = 9.410e-07
# Finished cycle # 000559 in  0.028673 seconds, solution distance = 9.319e-07
# ...
# Finished cycle # 000818 in  0.037005 seconds, solution distance = 7.524e-08
# Finished cycle # 000819 in  0.036709 seconds, solution distance = 7.452e-08
# Finished cycle # 000820 in  0.044288 seconds, solution distance = 7.380e-08
# Finished cycle # 000821 in  0.032268 seconds, solution distance = 7.309e-08
# Finished cycle # 000822 in  0.031698 seconds, solution distance = 7.239e-08
# Finished cycle # 000823 in  0.034896 seconds, solution distance = 7.169e-08
# Finished cycle # 000824 in  0.033119 seconds, solution distance = 7.100e-08
# Finished cycle # 000825 in  0.030931 seconds, solution distance = 7.032e-08
# Finished cycle # 000826 in  0.029971 seconds, solution distance = 6.964e-08
# Finished cycle # 000827 in  0.030789 seconds, solution distance = 6.897e-08
# Finished cycle # 000828 in  0.028665 seconds, solution distance = 6.831e-08
# Finished cycle # 000829 in  0.028851 seconds, solution distance = 6.765e-08
# Finished cycle # 000830 in  0.029054 seconds, solution distance = 6.700e-08
# Finished cycle # 000831 in  0.028809 seconds, solution distance = 6.635e-08
# Finished cycle # 000832 in  0.029002 seconds, solution distance = 6.571e-08
# Finished cycle # 000833 in  0.029479 seconds, solution distance = 6.508e-08
# Finished cycle # 000834 in  0.029818 seconds, solution distance = 6.446e-08
# Finished cycle # 000835 in  0.029444 seconds, solution distance = 6.384e-08
# Finished cycle # 000836 in  0.029704 seconds, solution distance = 6.322e-08
# Finished cycle # 000837 in  0.031485 seconds, solution distance = 6.261e-08
# Finished cycle # 000838 in  0.029026 seconds, solution distance = 6.201e-08
# Finished cycle # 000839 in  0.029608 seconds, solution distance = 6.141e-08
# Finished cycle # 000840 in  0.036958 seconds, solution distance = 6.082e-08
# Finished cycle # 000841 in  0.035131 seconds, solution distance = 6.024e-08
# Finished cycle # 000842 in  0.040480 seconds, solution distance = 5.966e-08
# Finished cycle # 000843 in  0.045321 seconds, solution distance = 5.908e-08
# Finished cycle # 000844 in  0.050128 seconds, solution distance = 5.851e-08
# Finished cycle # 000845 in  0.043010 seconds, solution distance = 5.795e-08
# Finished cycle # 000846 in  0.035066 seconds, solution distance = 5.739e-08
# Finished cycle # 000847 in  0.028791 seconds, solution distance = 5.684e-08
# Finished cycle # 000848 in  0.035232 seconds, solution distance = 5.629e-08
# Finished cycle # 000849 in  0.034573 seconds, solution distance = 5.575e-08
# Finished cycle # 000850 in  0.029001 seconds, solution distance = 5.521e-08
# Finished cycle # 000851 in  0.033637 seconds, solution distance = 5.468e-08
# Finished cycle # 000852 in  0.034015 seconds, solution distance = 5.416e-08
# Finished cycle # 000853 in  0.029625 seconds, solution distance = 5.364e-08
# Finished cycle # 000854 in  0.034762 seconds, solution distance = 5.312e-08
# Finished cycle # 000855 in  0.032537 seconds, solution distance = 5.261e-08
# Finished cycle # 000856 in  0.029803 seconds, solution distance = 5.210e-08
# Finished cycle # 000857 in  0.033668 seconds, solution distance = 5.160e-08
# Finished cycle # 000858 in  0.033199 seconds, solution distance = 5.110e-08
# Finished cycle # 000859 in  0.031576 seconds, solution distance = 5.061e-08
# Finished cycle # 000860 in  0.036650 seconds, solution distance = 5.013e-08
# Finished cycle # 000861 in  0.035359 seconds, solution distance = 4.964e-08
# Finished cycle # 000862 in  0.029984 seconds, solution distance = 4.917e-08
# Finished cycle # 000863 in  0.037874 seconds, solution distance = 4.869e-08
# Finished cycle # 000864 in  0.036957 seconds, solution distance = 4.822e-08
# Finished cycle # 000865 in  0.028975 seconds, solution distance = 4.776e-08
# Finished cycle # 000866 in  0.037006 seconds, solution distance = 4.730e-08
# Finished cycle # 000867 in  0.038227 seconds, solution distance = 4.684e-08
# Finished cycle # 000868 in  0.032583 seconds, solution distance = 4.639e-08
# Finished cycle # 000869 in  0.032355 seconds, solution distance = 4.595e-08
# Finished cycle # 000870 in  0.033484 seconds, solution distance = 4.551e-08
# Finished cycle # 000871 in  0.028490 seconds, solution distance = 4.507e-08
# Finished cycle # 000872 in  0.033020 seconds, solution distance = 4.463e-08
# Finished cycle # 000873 in  0.029795 seconds, solution distance = 4.420e-08
# Finished cycle # 000874 in  0.029807 seconds, solution distance = 4.378e-08
# Finished cycle # 000875 in  0.032305 seconds, solution distance = 4.336e-08
# Finished cycle # 000876 in  0.031736 seconds, solution distance = 4.294e-08
# Finished cycle # 000877 in  0.032295 seconds, solution distance = 4.253e-08
# Finished cycle # 000878 in  0.033769 seconds, solution distance = 4.212e-08
# Finished cycle # 000879 in  0.028908 seconds, solution distance = 4.171e-08
# Finished cycle # 000880 in  0.036985 seconds, solution distance = 4.131e-08
# Finished cycle # 000881 in  0.032311 seconds, solution distance = 4.091e-08
# Finished cycle # 000882 in  0.029750 seconds, solution distance = 4.052e-08
# Finished cycle # 000883 in  0.031747 seconds, solution distance = 4.013e-08
# Finished cycle # 000884 in  0.029079 seconds, solution distance = 3.974e-08
# Finished cycle # 000885 in  0.035023 seconds, solution distance = 3.936e-08
# Finished cycle # 000886 in  0.029490 seconds, solution distance = 3.898e-08
# Finished cycle # 000887 in  0.029063 seconds, solution distance = 3.861e-08
# Finished cycle # 000888 in  0.032819 seconds, solution distance = 3.824e-08
# Finished cycle # 000889 in  0.035113 seconds, solution distance = 3.787e-08
# Finished cycle # 000890 in  0.030538 seconds, solution distance = 3.750e-08
# Finished cycle # 000891 in  0.031324 seconds, solution distance = 3.714e-08
# Finished cycle # 000892 in  0.030192 seconds, solution distance = 3.679e-08
# Finished cycle # 000893 in  0.029288 seconds, solution distance = 3.643e-08
# Finished cycle # 000894 in  0.029750 seconds, solution distance = 3.608e-08
# Finished cycle # 000895 in  0.028818 seconds, solution distance = 3.573e-08
# Finished cycle # 000896 in  0.033625 seconds, solution distance = 3.539e-08
# Finished cycle # 000897 in  0.030856 seconds, solution distance = 3.505e-08
# Finished cycle # 000898 in  0.030035 seconds, solution distance = 3.471e-08
# Finished cycle # 000899 in  0.030058 seconds, solution distance = 3.438e-08
# Finished cycle # 000900 in  0.029101 seconds, solution distance = 3.405e-08
# Finished cycle # 000901 in  0.029747 seconds, solution distance = 3.372e-08
# Finished cycle # 000902 in  0.029670 seconds, solution distance = 3.340e-08
# Finished cycle # 000903 in  0.030368 seconds, solution distance = 3.308e-08
# Finished cycle # 000904 in  0.032320 seconds, solution distance = 3.276e-08
# Finished cycle # 000905 in  0.033700 seconds, solution distance = 3.244e-08
# Finished cycle # 000906 in  0.029338 seconds, solution distance = 3.213e-08
# Finished cycle # 000907 in  0.029785 seconds, solution distance = 3.182e-08
# Finished cycle # 000908 in  0.028973 seconds, solution distance = 3.151e-08
# Finished cycle # 000909 in  0.034775 seconds, solution distance = 3.121e-08
# Finished cycle # 000910 in  0.032438 seconds, solution distance = 3.091e-08
# Finished cycle # 000911 in  0.028825 seconds, solution distance = 3.061e-08
# Finished cycle # 000912 in  0.030706 seconds, solution distance = 3.032e-08
# Finished cycle # 000913 in  0.029441 seconds, solution distance = 3.003e-08
# Finished cycle # 000914 in  0.029155 seconds, solution distance = 2.974e-08
# Finished cycle # 000915 in  0.034106 seconds, solution distance = 2.945e-08
# Finished cycle # 000916 in  0.029002 seconds, solution distance = 2.917e-08
# Finished cycle # 000917 in  0.030576 seconds, solution distance = 2.889e-08
# Finished cycle # 000918 in  0.032162 seconds, solution distance = 2.861e-08
# Finished cycle # 000919 in  0.033715 seconds, solution distance = 2.834e-08
# Finished cycle # 000920 in  0.031143 seconds, solution distance = 2.806e-08
# Finished cycle # 000921 in  0.028209 seconds, solution distance = 2.779e-08
# Finished cycle # 000922 in  0.031016 seconds, solution distance = 2.753e-08
# Finished cycle # 000923 in  0.028210 seconds, solution distance = 2.726e-08
# Finished cycle # 000924 in  0.029790 seconds, solution distance = 2.700e-08
# Finished cycle # 000925 in  0.028530 seconds, solution distance = 2.674e-08
# Finished cycle # 000926 in  0.028409 seconds, solution distance = 2.648e-08
# Finished cycle # 000927 in  0.029104 seconds, solution distance = 2.623e-08
# Finished cycle # 000928 in  0.028022 seconds, solution distance = 2.597e-08
# Finished cycle # 000929 in  0.030453 seconds, solution distance = 2.572e-08
# Finished cycle # 000930 in  0.029245 seconds, solution distance = 2.548e-08
# Finished cycle # 000931 in  0.029378 seconds, solution distance = 2.523e-08
# Finished cycle # 000932 in  0.028711 seconds, solution distance = 2.499e-08
# Finished cycle # 000933 in  0.030466 seconds, solution distance = 2.475e-08
# Finished cycle # 000934 in  0.029489 seconds, solution distance = 2.451e-08
# Finished cycle # 000935 in  0.030477 seconds, solution distance = 2.428e-08
# Finished cycle # 000936 in  0.034196 seconds, solution distance = 2.404e-08
# Finished cycle # 000937 in  0.028659 seconds, solution distance = 2.381e-08
# Finished cycle # 000938 in  0.030055 seconds, solution distance = 2.358e-08
# Finished cycle # 000939 in  0.028992 seconds, solution distance = 2.335e-08
# Finished cycle # 000940 in  0.030952 seconds, solution distance = 2.313e-08
# Finished cycle # 000941 in  0.030956 seconds, solution distance = 2.291e-08
# Finished cycle # 000942 in  0.030808 seconds, solution distance = 2.269e-08
# Finished cycle # 000943 in  0.030560 seconds, solution distance = 2.247e-08
# Finished cycle # 000944 in  0.030716 seconds, solution distance = 2.225e-08
# Finished cycle # 000945 in  0.032426 seconds, solution distance = 2.204e-08
# Finished cycle # 000946 in  0.029684 seconds, solution distance = 2.183e-08
# Finished cycle # 000947 in  0.030292 seconds, solution distance = 2.162e-08
# Finished cycle # 000948 in  0.029657 seconds, solution distance = 2.141e-08
# Finished cycle # 000949 in  0.028856 seconds, solution distance = 2.120e-08
# Finished cycle # 000950 in  0.030979 seconds, solution distance = 2.100e-08
# Finished cycle # 000951 in  0.029148 seconds, solution distance = 2.080e-08
# Finished cycle # 000952 in  0.032069 seconds, solution distance = 2.060e-08
# Finished cycle # 000953 in  0.031820 seconds, solution distance = 2.040e-08
# Finished cycle # 000954 in  0.028086 seconds, solution distance = 2.020e-08
# Finished cycle # 000955 in  0.036610 seconds, solution distance = 2.001e-08
# Finished cycle # 000956 in  0.028829 seconds, solution distance = 1.982e-08
# Finished cycle # 000957 in  0.031734 seconds, solution distance = 1.963e-08
# Finished cycle # 000958 in  0.035739 seconds, solution distance = 1.944e-08
# Finished cycle # 000959 in  0.030454 seconds, solution distance = 1.925e-08
# Finished cycle # 000960 in  0.032964 seconds, solution distance = 1.906e-08
# Finished cycle # 000961 in  0.031979 seconds, solution distance = 1.888e-08
# Finished cycle # 000962 in  0.030669 seconds, solution distance = 1.870e-08
# Finished cycle # 000963 in  0.032491 seconds, solution distance = 1.852e-08
# Finished cycle # 000964 in  0.032168 seconds, solution distance = 1.834e-08
# Finished cycle # 000965 in  0.029274 seconds, solution distance = 1.817e-08
# Finished cycle # 000966 in  0.031386 seconds, solution distance = 1.799e-08
# Finished cycle # 000967 in  0.029808 seconds, solution distance = 1.782e-08
# Finished cycle # 000968 in  0.028615 seconds, solution distance = 1.765e-08
# Finished cycle # 000969 in  0.029264 seconds, solution distance = 1.748e-08
# Finished cycle # 000970 in  0.029334 seconds, solution distance = 1.731e-08
# Finished cycle # 000971 in  0.029491 seconds, solution distance = 1.714e-08
# Finished cycle # 000972 in  0.032662 seconds, solution distance = 1.698e-08
# Finished cycle # 000973 in  0.035533 seconds, solution distance = 1.681e-08
# Finished cycle # 000974 in  0.030736 seconds, solution distance = 1.665e-08
# Finished cycle # 000975 in  0.028580 seconds, solution distance = 1.649e-08
# Finished cycle # 000976 in  0.028534 seconds, solution distance = 1.633e-08
# Finished cycle # 000977 in  0.030165 seconds, solution distance = 1.618e-08
# Finished cycle # 000978 in  0.031228 seconds, solution distance = 1.602e-08
# Finished cycle # 000979 in  0.030232 seconds, solution distance = 1.587e-08
# Finished cycle # 000980 in  0.029227 seconds, solution distance = 1.571e-08
# Finished cycle # 000981 in  0.031094 seconds, solution distance = 1.556e-08
# Finished cycle # 000982 in  0.028889 seconds, solution distance = 1.541e-08
# Finished cycle # 000983 in  0.028185 seconds, solution distance = 1.526e-08
# Finished cycle # 000984 in  0.027463 seconds, solution distance = 1.512e-08
# Finished cycle # 000985 in  0.030782 seconds, solution distance = 1.497e-08
# Finished cycle # 000986 in  0.027898 seconds, solution distance = 1.483e-08
# Finished cycle # 000987 in  0.029509 seconds, solution distance = 1.469e-08
# Finished cycle # 000988 in  0.028105 seconds, solution distance = 1.454e-08
# Finished cycle # 000989 in  0.027634 seconds, solution distance = 1.440e-08
# Finished cycle # 000990 in  0.027199 seconds, solution distance = 1.427e-08
# Finished cycle # 000991 in  0.027384 seconds, solution distance = 1.413e-08
# Finished cycle # 000992 in  0.027190 seconds, solution distance = 1.399e-08
# Finished cycle # 000993 in  0.027673 seconds, solution distance = 1.386e-08
# Finished cycle # 000994 in  0.027415 seconds, solution distance = 1.373e-08
# Finished cycle # 000995 in  0.033915 seconds, solution distance = 1.359e-08
# Finished cycle # 000996 in  0.029797 seconds, solution distance = 1.346e-08
# Finished cycle # 000997 in  0.032300 seconds, solution distance = 1.333e-08
# Finished cycle # 000998 in  0.033524 seconds, solution distance = 1.320e-08
# Finished cycle # 000999 in  0.032119 seconds, solution distance = 1.308e-08
# Finished cycle # 001000 in  0.030057 seconds, solution distance = 1.295e-08
# Finished cycle # 001001 in  0.031936 seconds, solution distance = 1.283e-08
# Finished cycle # 001002 in  0.028751 seconds, solution distance = 1.270e-08
# Finished cycle # 001003 in  0.035094 seconds, solution distance = 1.258e-08
# Finished cycle # 001004 in  0.032766 seconds, solution distance = 1.246e-08
# Finished cycle # 001005 in  0.028184 seconds, solution distance = 1.234e-08
# Finished cycle # 001006 in  0.035124 seconds, solution distance = 1.222e-08
# Finished cycle # 001007 in  0.037801 seconds, solution distance = 1.210e-08
# Finished cycle # 001008 in  0.027664 seconds, solution distance = 1.199e-08
# Finished cycle # 001009 in  0.031906 seconds, solution distance = 1.187e-08
# Finished cycle # 001010 in  0.031164 seconds, solution distance = 1.176e-08
# Finished cycle # 001011 in  0.029485 seconds, solution distance = 1.165e-08
# Finished cycle # 001012 in  0.031307 seconds, solution distance = 1.153e-08
# Finished cycle # 001013 in  0.027797 seconds, solution distance = 1.142e-08
# Finished cycle # 001014 in  0.029276 seconds, solution distance = 1.131e-08
# Finished cycle # 001015 in  0.027880 seconds, solution distance = 1.120e-08
# Finished cycle # 001016 in  0.033520 seconds, solution distance = 1.110e-08
# Finished cycle # 001017 in  0.029294 seconds, solution distance = 1.099e-08
# Finished cycle # 001018 in  0.027686 seconds, solution distance = 1.088e-08
# Finished cycle # 001019 in  0.030997 seconds, solution distance = 1.078e-08
# Finished cycle # 001020 in  0.028310 seconds, solution distance = 1.068e-08
# Finished cycle # 001021 in  0.029875 seconds, solution distance = 1.057e-08
# Finished cycle # 001022 in  0.031436 seconds, solution distance = 1.047e-08
# Finished cycle # 001023 in  0.029813 seconds, solution distance = 1.037e-08
# Finished cycle # 001024 in  0.034821 seconds, solution distance = 1.027e-08
# Finished cycle # 001025 in  0.034353 seconds, solution distance = 1.017e-08
# Finished cycle # 001026 in  0.030114 seconds, solution distance = 1.007e-08
# Finished cycle # 001027 in  0.029215 seconds, solution distance = 9.977e-09

# %%
# Plot GICNrmFailsButGICRawHolds

#fig = plt.figure(figsize = (12,8))
# ax  = fig.add_subplot(111)

fig, ax = plt.subplots(figsize = (12,8))
[xMin,xMax] = [0.0,8.0]
yMin = 0.0
yMax = GICNrmFailsButGICRawHolds.solution[0].c_where_Ex_mtp1_minus_mt_eq_0(xMax)*1.3

mPltVals = np.linspace(xMin, xMax, mPts)

if latexExists:
    c_Stable_Ind_txt = "$\mathbb{E}_{t}[\Delta m_{t+1}] = 0$"
    c_Stable_Agg_txt = "$\mathbb{E}_{t}[\pmb{\mathrm{m}}_{t+1}/\pmb{\mathrm{m}}_{t}] = \Gamma$"
else:
    c_Stable_Ind_txt = "$\mathsf{E}_{t}[\Delta m_{t+1}] = 0$"
    c_Stable_Agg_txt = "$\mathsf{E}_{t}[\mathbf{m}_{t+1}/\mathbf{m}_{t}] = \Gamma$"


cVals_Lmting_color="black"
c_Stable_Agg_color="black"#"blue"
c_Stable_Ind_color="black"  #"red"

cVals_Lmting=GICNrmFailsButGICRawHolds.solution[0].cFunc(mPltVals)
c_Stable_Ind=GICNrmFailsButGICRawHolds.solution[0].c_where_Ex_mtp1_minus_mt_eq_0(mPltVals)
c_Stable_Agg=GICNrmFailsButGICRawHolds.solution[0].c_where_Ex_PermShk_times_mtp1_minus_mt_eq_0(mPltVals)

cVals_Lmting_lbl, = ax.plot(mPltVals, cVals_Lmting, color=cVals_Lmting_color)
c_Stable_Ind_lbl, = ax.plot(mPltVals, c_Stable_Ind, 
                            color=c_Stable_Ind_color,linestyle="dashed",label=c_Stable_Ind_txt)
c_Stable_Agg_lbl, = ax.plot(mPltVals, c_Stable_Agg, 
                            color=c_Stable_Agg_color,linestyle="dotted",label=c_Stable_Agg_txt)

ax.set_xlim(xMin,xMax)
ax.set_ylim(yMin,yMax)
ax.set_xlabel("$\mathit{m}$",fontweight='bold',fontsize=fsmid,loc="right")
ax.set_ylabel("$\mathit{c}$",fontweight='bold',fontsize=fsmid,loc="top",rotation=0)
# plt.text(xMin,yMax+0.03, "$c$", fontsize=26)
# plt.text(xMax-0.05,yMin, "$m$", fontsize=26)
ax.tick_params(labelbottom=False, labelleft=False, left='off',
                right='off', bottom='off', top='off')

#ax.arrow(0.98, 0.62, -0.2, 0, head_width=0.02, width=0.001,facecolor='black', length_includes_head='True')
#ax.arrow(2.2, 1.2, 0.3, -0.05, head_width=0.02, width=0.001,facecolor='black', length_includes_head='True')

ax.legend(handles=[c_Stable_Ind_lbl,c_Stable_Agg_lbl])
ax.legend(prop=dict(size=fsmid))

mNrmStE = GICNrmFailsButGICRawHolds.solution[0].mNrmStE
cNrmStE = c_Stable_Agg=GICNrmFailsButGICRawHolds.solution[0].c_where_Ex_PermShk_times_mtp1_minus_mt_eq_0(mNrmStE)
#mNrmStE_lbl, = ax.plot([mNrmStE,mNrmStE],[yMin,yMax],color="green",linestyle="--",label='Pseudo-Steady-State: $\mathbb{E}_{t}[\pmb{m}_{t+1}/\pmb{m}_{t}]=\Gamma$')

ax.plot(mNrmStE,cNrmStE,marker=".",markersize=15,color="black") # Dot at StE point
ax.text(1, 0.6, "$\mathrm{c}(m_{t})$", fontsize=fsmid) # label cFunc

if latexExists:
    ax.text(mNrmStE+0.02,cNrmStE-0.10, r"$\nwarrow$", fontsize=fsmid)
    ax.text(mNrmStE+0.25,cNrmStE-0.18, r"$\phantom{\nwarrow} \StE{\mRat}$", fontsize=fsmid)
else:
    ax.text(mNrmStE+0.02,cNrmStE-0.10, r"$\nwarrow$", fontsize=fsmid)
    ax.text(mNrmStE+0.25,cNrmStE-0.18, r"$\phantom{\nwarrow} \StE{\mRat}$", fontsize=fsmid)

make('GICNrmFailsButGICRawHolds')
print('Finite mNrmStE but infinite mNrmTrg')
# Out:
# Saving figure GICNrmFailsButGICRawHolds in ../../Figures
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# /Volumes/Sync/Sys/OSX/linked/root/usr/local/bin/anaconda/lib/python3.8/site-packages/matplotlib/texmanager.py in _run_checked_subprocess(self, command, tex)
#     274         try:
# --> 275             report = subprocess.check_output(command,
#     276                                              cwd=self.texcache,
#
# /Volumes/Sync/Sys/OSX/linked/root/usr/local/bin/anaconda/lib/python3.8/subprocess.py in check_output(timeout, *popenargs, **kwargs)
#     414
# --> 415     return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
#     416                **kwargs).stdout
#
# /Volumes/Sync/Sys/OSX/linked/root/usr/local/bin/anaconda/lib/python3.8/subprocess.py in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     515         if check and retcode:
# --> 516             raise CalledProcessError(retcode, process.args,
#     517                                      output=stdout, stderr=stderr)
#
# CalledProcessError: Command '['latex', '-interaction=nonstopmode', '--halt-on-error', '/Users/ccarroll/.matplotlib/tex.cache/c3ac18443012cb585107084763447343.tex']' returned non-zero exit status 1.
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-7-643b93e551fa> in <module>
#      62     ax.text(mNrmStE+0.25,cNrmStE-0.18, r"$\phantom{\nwarrow} \StE{\mRat}$", fontsize=fsmid)
#      63
# ---> 64 make('GICNrmFailsButGICRawHolds')
#      65 print('Finite mNrmStE but infinite mNrmTrg')
#
# <ipython-input-1-1d82005df586> in make(figure_name, target_dir)
#      53 # this can be removed if we pass in saveFigs and drawFigs in every call to make('figure')
#      54 def make(figure_name, target_dir="../../Figures"):
# ---> 55     make_figs(figure_name, saveFigs, drawFigs, target_dir)
#
# /Volumes/Data/Code/ARK/HARKive/HARK/HARK/utilities.py in make_figs(figure_name, saveFigs, drawFigs, target_dir)
#     984         # Save the figures in several formats
#     985         print("Saving figure {} in {}".format(figure_name, target_dir))
# --> 986         plt.savefig(
#     987             os.path.join(target_dir, "{}.jpg".format(figure_name))
#     988         )  # For web/html
#
# /Volumes/Sync/Sys/OSX/linked/root/usr/local/bin/anaconda/lib/python3.8/site-packages/matplotlib/pyplot.py in savefig(*args, **kwargs)
#     857 def savefig(*args, **kwargs):
#     858     fig = gcf()
# --> 859     res = fig.savefig(*args, **kwargs)
#     860     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     861     return res
#
# /Volumes/Sync/Sys/OSX/linked/root/usr/local/bin/anaconda/lib/python3.8/site-packages/matplotlib/figure.py in savefig(self, fname, transparent, **kwargs)
#    2309                 patch.set_edgecolor('none')
#    2310
# -> 2311         self.canvas.print_figure(fname, **kwargs)
#    2312
#    2313         if transparent:
#
# /Volumes/Sync/Sys/OSX/linked/root/usr/local/bin/anaconda/lib/python3.8/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2208
#    2209             try:
# -> 2210                 result = print_method(
#    2211                     filename,
#    2212                     dpi=dpi,
#
# /Volumes/Sync/Sys/OSX/linked/root/usr/local/bin/anaconda/lib/python3.8/site-packages/matplotlib/backend_bases.py in wrapper(*args, **kwargs)
#    1637             kwargs.pop(arg)
#    1638
# -> 1639         return func(*args, **kwargs)
#    1640
#    1641     return wrapper
#
# /Volumes/Sync/Sys/OSX/linked/root/usr/local/bin/anaconda/lib/python3.8/site-packages/matplotlib/cbook/deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     409                          else deprecation_addendum,
#     410                 **kwargs)
# --> 411         return func(*inner_args, **inner_kwargs)
#     412
#     413     return wrapper
#
# /Volumes/Sync/Sys/OSX/linked/root/usr/local/bin/anaconda/lib/python3.8/site-packages/matplotlib/cbook/deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     409                          else deprecation_addendum,
#     410                 **kwargs)
# --> 411         return func(*inner_args, **inner_kwargs)
#     412
#     413     return wrapper
#
# /Volumes/Sync/Sys/OSX/linked/root/usr/local/bin/anaconda/lib/python3.8/site-packages/matplotlib/cbook/deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     409                          else deprecation_addendum,
#     410                 **kwargs)
# --> 411         return func(*inner_args, **inner_kwargs)
#     412
#     413     return wrapper
#
# /Volumes/Sync/Sys/OSX/linked/root/usr/local/bin/anaconda/lib/python3.8/site-packages/matplotlib/cbook/deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     409                          else deprecation_addendum,
#     410                 **kwargs)
# --> 411         return func(*inner_args, **inner_kwargs)
#     412
#     413     return wrapper
#
# /Volumes/Sync/Sys/OSX/linked/root/usr/local/bin/anaconda/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py in print_jpg(self, filename_or_obj, dryrun, pil_kwargs, *args, **kwargs)
#     568         try:
#     569             self.figure.set_facecolor(a * np.array([r, g, b]) + 1 - a)
# --> 570             FigureCanvasAgg.draw(self)
#     571         finally:
#     572             self.figure.set_facecolor((r, g, b, a))
#
# /Volumes/Sync/Sys/OSX/linked/root/usr/local/bin/anaconda/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py in draw(self)
#     405              (self.toolbar._wait_cursor_for_draw_cm() if self.toolbar
#     406               else nullcontext()):
# --> 407             self.figure.draw(self.renderer)
#     408             # A GUI class may be need to update a window using this draw, so
#     409             # don't forget to call the superclass.
#
# /Volumes/Sync/Sys/OSX/linked/root/usr/local/bin/anaconda/lib/python3.8/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      39                 renderer.start_filter()
#      40
# ---> 41             return draw(artist, renderer, *args, **kwargs)
#      42         finally:
#      43             if artist.get_agg_filter() is not None:
#
# /Volumes/Sync/Sys/OSX/linked/root/usr/local/bin/anaconda/lib/python3.8/site-packages/matplotlib/figure.py in draw(self, renderer)
#    1861
#    1862             self.patch.draw(renderer)
# -> 1863             mimage._draw_list_compositing_images(
#    1864                 renderer, self, artists, self.suppressComposite)
#    1865
#
# /Volumes/Sync/Sys/OSX/linked/root/usr/local/bin/anaconda/lib/python3.8/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     129     if not_composite or not has_images:
#     130         for a in artists:
# --> 131             a.draw(renderer)
#     132     else:
#     133         # Composite any adjacent images together
#
# /Volumes/Sync/Sys/OSX/linked/root/usr/local/bin/anaconda/lib/python3.8/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      39                 renderer.start_filter()
#      40
# ---> 41             return draw(artist, renderer, *args, **kwargs)
#      42         finally:
#      43             if artist.get_agg_filter() is not None:
#
# /Volumes/Sync/Sys/OSX/linked/root/usr/local/bin/anaconda/lib/python3.8/site-packages/matplotlib/cbook/deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     409                          else deprecation_addendum,
#     410                 **kwargs)
# --> 411         return func(*inner_args, **inner_kwargs)
#     412
#     413     return wrapper
#
# /Volumes/Sync/Sys/OSX/linked/root/usr/local/bin/anaconda/lib/python3.8/site-packages/matplotlib/axes/_base.py in draw(self, renderer, inframe)
#    2745             renderer.stop_rasterizing()
#    2746
# -> 2747         mimage._draw_list_compositing_images(renderer, self, artists)
#    2748
#    2749         renderer.close_group('axes')
#
# /Volumes/Sync/Sys/OSX/linked/root/usr/local/bin/anaconda/lib/python3.8/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     129     if not_composite or not has_images:
#     130         for a in artists:
# --> 131             a.draw(renderer)
#     132     else:
#     133         # Composite any adjacent images together
#
# /Volumes/Sync/Sys/OSX/linked/root/usr/local/bin/anaconda/lib/python3.8/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      39                 renderer.start_filter()
#      40
# ---> 41             return draw(artist, renderer, *args, **kwargs)
#      42         finally:
#      43             if artist.get_agg_filter() is not None:
#
# /Volumes/Sync/Sys/OSX/linked/root/usr/local/bin/anaconda/lib/python3.8/site-packages/matplotlib/text.py in draw(self, renderer)
#     679
#     680         with _wrap_text(self) as textobj:
# --> 681             bbox, info, descent = textobj._get_layout(renderer)
#     682             trans = textobj.get_transform()
#     683
#
# /Volumes/Sync/Sys/OSX/linked/root/usr/local/bin/anaconda/lib/python3.8/site-packages/matplotlib/text.py in _get_layout(self, renderer)
#     293             clean_line, ismath = self._preprocess_math(line)
#     294             if clean_line:
# --> 295                 w, h, d = renderer.get_text_width_height_descent(
#     296                     clean_line, self._fontproperties, ismath=ismath)
#     297             else:
#
# /Volumes/Sync/Sys/OSX/linked/root/usr/local/bin/anaconda/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py in get_text_width_height_descent(self, s, prop, ismath)
#     225             texmanager = self.get_texmanager()
#     226             fontsize = prop.get_size_in_points()
# --> 227             w, h, d = texmanager.get_text_width_height_descent(
#     228                 s, fontsize, renderer=self)
#     229             return w, h, d
#
# /Volumes/Sync/Sys/OSX/linked/root/usr/local/bin/anaconda/lib/python3.8/site-packages/matplotlib/texmanager.py in get_text_width_height_descent(self, tex, fontsize, renderer)
#     421         else:
#     422             # use dviread.
# --> 423             dvifile = self.make_dvi(tex, fontsize)
#     424             with dviread.Dvi(dvifile, 72 * dpi_fraction) as dvi:
#     425                 page, = dvi
#
# /Volumes/Sync/Sys/OSX/linked/root/usr/local/bin/anaconda/lib/python3.8/site-packages/matplotlib/texmanager.py in make_dvi(self, tex, fontsize)
#     307             texfile = self.make_tex(tex, fontsize)
#     308             with cbook._lock_path(texfile):
# --> 309                 self._run_checked_subprocess(
#     310                     ["latex", "-interaction=nonstopmode", "--halt-on-error",
#     311                      texfile], tex)
#
# /Volumes/Sync/Sys/OSX/linked/root/usr/local/bin/anaconda/lib/python3.8/site-packages/matplotlib/texmanager.py in _run_checked_subprocess(self, command, tex)
#     281                 'found'.format(command[0])) from exc
#     282         except subprocess.CalledProcessError as exc:
# --> 283             raise RuntimeError(
#     284                 '{prog} was not able to process the following string:\n'
#     285                 '{tex!r}\n\n'
#
# RuntimeError: latex was not able to process the following string:
# b'$\\\\phantom{\\\\nwarrow} \\\\StE{\\\\mRat}$'
#
# Here is the full report generated by latex:
# This is pdfTeX, Version 3.14159265-2.6-1.40.21 (TeX Live 2020) (preloaded format=latex)
#  \write18 enabled.
# entering extended mode
# (/Users/ccarroll/.matplotlib/tex.cache/c3ac18443012cb585107084763447343.tex
# LaTeX2e <2020-02-02> patch level 5
# L3 programming layer <2020-03-06> (/usr/local/texlive/2020/texmf-dist/tex/latex/base/article.cls
# Document Class: article 2019/12/20 v1.4l Standard LaTeX document class
# (/usr/local/texlive/2020/texmf-dist/tex/latex/base/size10.clo)) (/usr/local/texlive/2020/texmf-dist/tex/latex/type1cm/type1cm.sty) (/usr/local/texlive/2020/texmf-dist/tex/latex/cm-super/type1ec.sty (/usr/local/texlive/2020/texmf-dist/tex/latex/base/t1cmr.fd)) (/usr/local/texlive/2020/texmf-dist/tex/latex/base/inputenc.sty) (/usr/local/texlive/2020/texmf-dist/tex/latex/geometry/geometry.sty (/usr/local/texlive/2020/texmf-dist/tex/latex/graphics/keyval.sty) (/usr/local/texlive/2020/texmf-dist/tex/generic/iftex/ifvtex.sty (/usr/local/texlive/2020/texmf-dist/tex/generic/iftex/iftex.sty))
#
# Package geometry Warning: Over-specification in `h'-direction.
#     `width' (5058.9pt) is ignored.
#
#
# Package geometry Warning: Over-specification in `v'-direction.
#     `height' (5058.9pt) is ignored.
#
# ) (/usr/local/texlive/2020/texmf-dist/tex/latex/amsmath/amsmath.sty
# For additional information on amsmath, use the `?' option.
# (/usr/local/texlive/2020/texmf-dist/tex/latex/amsmath/amstext.sty (/usr/local/texlive/2020/texmf-dist/tex/latex/amsmath/amsgen.sty)) (/usr/local/texlive/2020/texmf-dist/tex/latex/amsmath/amsbsy.sty) (/usr/local/texlive/2020/texmf-dist/tex/latex/amsmath/amsopn.sty)) (/usr/local/texlive/2020/texmf-dist/tex/latex/amsfonts/amsfonts.sty) (/usr/local/texlive/2020/texmf-dist/tex/latex/base/fontenc.sty) (/Volumes/Data/Papers/BufferStockTheory/BufferStockTheory-Public/Code/Python/latexdefs.tex) (/usr/local/texlive/2020/texmf-dist/tex/latex/base/textcomp.sty) (/usr/local/texlive/2020/texmf-dist/tex/latex/l3backend/l3backend-dvips.def)
# No file c3ac18443012cb585107084763447343.aux.
# *geometry* driver: auto-detecting
# *geometry* detected driver: dvips
# ! Undefined control sequence.
# l.19 {\rmfamily $\phantom{\nwarrow} \StE
#                                         {\mRat}$}
# No pages of output.
# Transcript written on c3ac18443012cb585107084763447343.log.
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# /Volumes/Sync/Sys/OSX/linked/root/usr/local/bin/anaconda/lib/python3.8/site-packages/matplotlib/texmanager.py in _run_checked_subprocess(self, command, tex)
#     274         try:
# --> 275             report = subprocess.check_output(command,
#     276                                              cwd=self.texcache,
#
# /Volumes/Sync/Sys/OSX/linked/root/usr/local/bin/anaconda/lib/python3.8/subprocess.py in check_output(timeout, *popenargs, **kwargs)
#     414
# --> 415     return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
#     416                **kwargs).stdout
#
# /Volumes/Sync/Sys/OSX/linked/root/usr/local/bin/anaconda/lib/python3.8/subprocess.py in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     515         if check and retcode:
# --> 516             raise CalledProcessError(retcode, process.args,
#     517                                      output=stdout, stderr=stderr)
#
# CalledProcessError: Command '['latex', '-interaction=nonstopmode', '--halt-on-error', '/Users/ccarroll/.matplotlib/tex.cache/c3ac18443012cb585107084763447343.tex']' returned non-zero exit status 1.
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# /Volumes/Sync/Sys/OSX/linked/root/usr/local/bin/anaconda/lib/python3.8/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# /Volumes/Sync/Sys/OSX/linked/root/usr/local/bin/anaconda/lib/python3.8/site-packages/IPython/core/pylabtools.py in <lambda>(fig)
#     246
#     247     if 'png' in formats:
# --> 248         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     249     if 'retina' in formats or 'png2x' in formats:
#     250         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# /Volumes/Sync/Sys/OSX/linked/root/usr/local/bin/anaconda/lib/python3.8/site-packages/IPython/core/pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     130         FigureCanvasBase(fig)
#     131
# --> 132     fig.canvas.print_figure(bytes_io, **kw)
#     133     data = bytes_io.getvalue()
#     134     if fmt == 'svg':
#
# /Volumes/Sync/Sys/OSX/linked/root/usr/local/bin/anaconda/lib/python3.8/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2191                            else suppress())
#    2192                     with ctx:
# -> 2193                         self.figure.draw(renderer)
#    2194
#    2195                     bbox_inches = self.figure.get_tightbbox(
#
# /Volumes/Sync/Sys/OSX/linked/root/usr/local/bin/anaconda/lib/python3.8/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      39                 renderer.start_filter()
#      40
# ---> 41             return draw(artist, renderer, *args, **kwargs)
#      42         finally:
#      43             if artist.get_agg_filter() is not None:
#
# /Volumes/Sync/Sys/OSX/linked/root/usr/local/bin/anaconda/lib/python3.8/site-packages/matplotlib/figure.py in draw(self, renderer)
#    1861
#    1862             self.patch.draw(renderer)
# -> 1863             mimage._draw_list_compositing_images(
#    1864                 renderer, self, artists, self.suppressComposite)
#    1865
#
# /Volumes/Sync/Sys/OSX/linked/root/usr/local/bin/anaconda/lib/python3.8/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     129     if not_composite or not has_images:
#     130         for a in artists:
# --> 131             a.draw(renderer)
#     132     else:
#     133         # Composite any adjacent images together
#
# /Volumes/Sync/Sys/OSX/linked/root/usr/local/bin/anaconda/lib/python3.8/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      39                 renderer.start_filter()
#      40
# ---> 41             return draw(artist, renderer, *args, **kwargs)
#      42         finally:
#      43             if artist.get_agg_filter() is not None:
#
# /Volumes/Sync/Sys/OSX/linked/root/usr/local/bin/anaconda/lib/python3.8/site-packages/matplotlib/cbook/deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     409                          else deprecation_addendum,
#     410                 **kwargs)
# --> 411         return func(*inner_args, **inner_kwargs)
#     412
#     413     return wrapper
#
# /Volumes/Sync/Sys/OSX/linked/root/usr/local/bin/anaconda/lib/python3.8/site-packages/matplotlib/axes/_base.py in draw(self, renderer, inframe)
#    2745             renderer.stop_rasterizing()
#    2746
# -> 2747         mimage._draw_list_compositing_images(renderer, self, artists)
#    2748
#    2749         renderer.close_group('axes')
#
# /Volumes/Sync/Sys/OSX/linked/root/usr/local/bin/anaconda/lib/python3.8/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     129     if not_composite or not has_images:
#     130         for a in artists:
# --> 131             a.draw(renderer)
#     132     else:
#     133         # Composite any adjacent images together
#
# /Volumes/Sync/Sys/OSX/linked/root/usr/local/bin/anaconda/lib/python3.8/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      39                 renderer.start_filter()
#      40
# ---> 41             return draw(artist, renderer, *args, **kwargs)
#      42         finally:
#      43             if artist.get_agg_filter() is not None:
#
# /Volumes/Sync/Sys/OSX/linked/root/usr/local/bin/anaconda/lib/python3.8/site-packages/matplotlib/text.py in draw(self, renderer)
#     679
#     680         with _wrap_text(self) as textobj:
# --> 681             bbox, info, descent = textobj._get_layout(renderer)
#     682             trans = textobj.get_transform()
#     683
#
# /Volumes/Sync/Sys/OSX/linked/root/usr/local/bin/anaconda/lib/python3.8/site-packages/matplotlib/text.py in _get_layout(self, renderer)
#     293             clean_line, ismath = self._preprocess_math(line)
#     294             if clean_line:
# --> 295                 w, h, d = renderer.get_text_width_height_descent(
#     296                     clean_line, self._fontproperties, ismath=ismath)
#     297             else:
#
# /Volumes/Sync/Sys/OSX/linked/root/usr/local/bin/anaconda/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py in get_text_width_height_descent(self, s, prop, ismath)
#     225             texmanager = self.get_texmanager()
#     226             fontsize = prop.get_size_in_points()
# --> 227             w, h, d = texmanager.get_text_width_height_descent(
#     228                 s, fontsize, renderer=self)
#     229             return w, h, d
#
# /Volumes/Sync/Sys/OSX/linked/root/usr/local/bin/anaconda/lib/python3.8/site-packages/matplotlib/texmanager.py in get_text_width_height_descent(self, tex, fontsize, renderer)
#     421         else:
#     422             # use dviread.
# --> 423             dvifile = self.make_dvi(tex, fontsize)
#     424             with dviread.Dvi(dvifile, 72 * dpi_fraction) as dvi:
#     425                 page, = dvi
#
# /Volumes/Sync/Sys/OSX/linked/root/usr/local/bin/anaconda/lib/python3.8/site-packages/matplotlib/texmanager.py in make_dvi(self, tex, fontsize)
#     307             texfile = self.make_tex(tex, fontsize)
#     308             with cbook._lock_path(texfile):
# --> 309                 self._run_checked_subprocess(
#     310                     ["latex", "-interaction=nonstopmode", "--halt-on-error",
#     311                      texfile], tex)
#
# /Volumes/Sync/Sys/OSX/linked/root/usr/local/bin/anaconda/lib/python3.8/site-packages/matplotlib/texmanager.py in _run_checked_subprocess(self, command, tex)
#     281                 'found'.format(command[0])) from exc
#     282         except subprocess.CalledProcessError as exc:
# --> 283             raise RuntimeError(
#     284                 '{prog} was not able to process the following string:\n'
#     285                 '{tex!r}\n\n'
#
# RuntimeError: latex was not able to process the following string:
# b'$\\\\phantom{\\\\nwarrow} \\\\StE{\\\\mRat}$'
#
# Here is the full report generated by latex:
# This is pdfTeX, Version 3.14159265-2.6-1.40.21 (TeX Live 2020) (preloaded format=latex)
#  \write18 enabled.
# entering extended mode
# (/Users/ccarroll/.matplotlib/tex.cache/c3ac18443012cb585107084763447343.tex
# LaTeX2e <2020-02-02> patch level 5
# L3 programming layer <2020-03-06> (/usr/local/texlive/2020/texmf-dist/tex/latex/base/article.cls
# Document Class: article 2019/12/20 v1.4l Standard LaTeX document class
# (/usr/local/texlive/2020/texmf-dist/tex/latex/base/size10.clo)) (/usr/local/texlive/2020/texmf-dist/tex/latex/type1cm/type1cm.sty) (/usr/local/texlive/2020/texmf-dist/tex/latex/cm-super/type1ec.sty (/usr/local/texlive/2020/texmf-dist/tex/latex/base/t1cmr.fd)) (/usr/local/texlive/2020/texmf-dist/tex/latex/base/inputenc.sty) (/usr/local/texlive/2020/texmf-dist/tex/latex/geometry/geometry.sty (/usr/local/texlive/2020/texmf-dist/tex/latex/graphics/keyval.sty) (/usr/local/texlive/2020/texmf-dist/tex/generic/iftex/ifvtex.sty (/usr/local/texlive/2020/texmf-dist/tex/generic/iftex/iftex.sty))
#
# Package geometry Warning: Over-specification in `h'-direction.
#     `width' (5058.9pt) is ignored.
#
#
# Package geometry Warning: Over-specification in `v'-direction.
#     `height' (5058.9pt) is ignored.
#
# ) (/usr/local/texlive/2020/texmf-dist/tex/latex/amsmath/amsmath.sty
# For additional information on amsmath, use the `?' option.
# (/usr/local/texlive/2020/texmf-dist/tex/latex/amsmath/amstext.sty (/usr/local/texlive/2020/texmf-dist/tex/latex/amsmath/amsgen.sty)) (/usr/local/texlive/2020/texmf-dist/tex/latex/amsmath/amsbsy.sty) (/usr/local/texlive/2020/texmf-dist/tex/latex/amsmath/amsopn.sty)) (/usr/local/texlive/2020/texmf-dist/tex/latex/amsfonts/amsfonts.sty) (/usr/local/texlive/2020/texmf-dist/tex/latex/base/fontenc.sty) (/Volumes/Data/Papers/BufferStockTheory/BufferStockTheory-Public/Code/Python/latexdefs.tex) (/usr/local/texlive/2020/texmf-dist/tex/latex/base/textcomp.sty) (/usr/local/texlive/2020/texmf-dist/tex/latex/l3backend/l3backend-dvips.def) (./c3ac18443012cb585107084763447343.aux)
# *geometry* driver: auto-detecting
# *geometry* detected driver: dvips
# ! Undefined control sequence.
# l.19 {\rmfamily $\phantom{\nwarrow} \StE
#                                         {\mRat}$}
# No pages of output.
# Transcript written on c3ac18443012cb585107084763447343.log.

# %% [markdown]
# In the [interactive dashboard](#interactive-dashboard), see what happens as changes in the time preference rate (or changes in risk $\sigma_\psi$) change the consumer from _normalized-growth-patient_ $(\Phi > \tilde{\Gamma})$ to _normalized-growth-impatient_ ($\Phi < \tilde{\Gamma}$)

# %% [markdown]
# As a foundation for the remaining figures, we define another instance of the class $\texttt{IndShockConsumerType}$, which has the same parameter values as the instance $\texttt{baseAgent}$ defined previously but is solved to convergence (our definition of an infinite horizon agent type) instead of only 100 periods

# %%
# Find the infinite horizon solution
baseAgent_Inf = IndShockConsumerType(cycles=0    # Infinite horizon
                                     , verbose=0 # solve silently 
                                     , **base_params)
baseAgent_Inf.solve()

# %% [markdown]
# ### [Target $m$, Expected Consumption Growth, and Permanent Income Growth](https://www.econ2.jhu.edu/people/ccarroll/papers/BufferStockTheory/#AnalysisoftheConvergedConsumptionFunction)
#
# The next figure, [Analysis of the Converged Consumption Function](https://www.econ2.jhu.edu/people/ccarroll/papers/BufferStockTheory/#cGroTargetFig), shows expected growth factors for the levels of consumption $\mathbf{c}$ and market resources $\mathbf{m}$ as a function of the market resources ratio $\mRat$ for a consumer behaving according to the converged consumption rule, along with the growth factor for an unconstrained perfect foresight consumer which is constant at $\Pat$ and the growth factor for permanent income which is constant at $\Gamma$.
#
# The growth factor for consumption can be computed without knowing the _level_ of the consumer's permanent income:
# \begin{eqnarray*}
# \mathbb{E}_{t}[\mathbf{c}_{t+1}/\mathbf{c}_{t}] & = & \mathbb{E}_{t}\left[\frac{\mathbf{p}_{t+1}\cNrm_{t+1}(m_{t+1})}{\mathbf{p}_{t}\cNrm_{t}(m_{t})}\right] \\
# & = & \mathbb{E}_{t}\left[\frac{\Gamma \psi_{t+1} \mathbf{p}_{t}}{\mathbf{p}_{t}}\frac{\cNrm_{t+1}(m_{t+1})}{\cNrm_{t}(m_{t})}\right] \\
# & = & \mathbb{E}_{t}\left[\frac{\Gamma \psi_{t+1} \cNrm_{t+1}(m_{t+1})}{\cNrm_{t}(m_{t})}\right]
# \end{eqnarray*}
#
# and similarly the growth factor for market resources is:
# \begin{eqnarray*}
# \mathbb{E}_{t}[\mathbf{m}_{t+1}/\mathbf{m}_{t}]
# & = & \mathbb{E}_{t}\left[\frac{\Gamma \psi_{t+1} \mNrm_{t+1}}{\mNrm_{t}}\right]
# \end{eqnarray*}

# %%
# Growth factors as a function of market resource ratio

color_cons = "blue"
color_mrkt = "red"
color_perm = "black"

mPlotMin = 0.0
mCalcMax = 50
mPlotMax = 2.20

# Get StE and target values
mNrmStE=baseAgent_Inf.solution[0].mNrmStE
mNrmTrg=baseAgent_Inf.solution[0].mNrmTrg

pts_num = 200 # Plot this many points

m_pts = np.linspace(1,mPlotMax,pts_num)        # values of m for plot
c_pts = baseAgent_Inf.solution[0].cFunc(m_pts) # values of c for plot 
a_pts = m_pts - c_pts                          # values of a 

Ex_cLev_tp1_Over_pLev_t = [baseAgent_Inf.solution[0].Ex_cLev_tp1_Over_pLev_t_from_at(a) for a in a_pts]
Ex_mLev_tp1_Over_pLev_t = [baseAgent_Inf.solution[0].Ex_mLev_tp1_Over_pLev_t_from_at(a) for a in a_pts]

Ex_cGro = np.array(Ex_cLev_tp1_Over_pLev_t)/c_pts
Ex_mGro = np.array(Ex_mLev_tp1_Over_pLev_t)/m_pts

# Retrieve parameters (makes code readable)
Rfree      = baseAgent_Inf.Rfree
DiscFac    = baseAgent_Inf.DiscFac
CRRA       = baseAgent_Inf.CRRA
PermGro    = baseAgent_Inf.PermGroFac[0]
mNrmStE    = baseAgent_Inf.solution[0].mNrmStE
mNrmTrg    = baseAgent_Inf.solution[0].mNrmTrg

# Absolute Patience Factor = lower bound of consumption growth factor
APF = (Rfree*DiscFac)**(1.0/CRRA)

# Create figure object 
fig = plt.figure(figsize = (12,8))
ax  = fig.add_subplot(111) # axes object 

# Plot the Absolute Patience Factor line
ax.plot([0,mPlotMax],[APF,APF],color=color_cons)

# Plot the Permanent Income Growth Factor line
ax.plot([0,mPlotMax],[PermGro,PermGro],color=color_perm)

# Plot the expected consumption growth factor
ax.plot(m_pts,Ex_cGro,color=color_cons)

# Plot the expected consumption growth factor on the right side of target m
ax.plot(m_pts,Ex_mGro,color="red")

# Axes limits 
GroFacMin = 0.98 #0.98
GroFacMax = 1.06 #1.08
xMin = 1.1 # 1.0

# Vertical lines at StE and Trg
mNrmStE_lbl, = ax.plot([mNrmStE,mNrmStE],[0,GroFacMax],color=color_mrkt,linestyle="--"
                       ,label='$\StE{m}:$ Pseudo-Steady-State: $\mathbb{E}_{t}[\pmb{\mathrm{m}}_{t+1}/\pmb{\mathrm{m}}_{t}]=\Gamma$')
mNrmTrg_lbl, = ax.plot([mNrmTrg,mNrmTrg],[0,GroFacMax],color=color_mrkt,linestyle="dotted"
                       ,label='$\Trg{m}:$ Target: $\mathbb{E}_{t}[m_{t+1}]=m_{t}$')
ax.text(mNrmStE-0.12,0.985, r'$\StE{m}\rightarrow$', fontsize = fsbig,fontweight='bold')
ax.text(mNrmTrg+0.01,0.985, r'$\leftarrow\Trg{m}$', fontsize = fsbig,fontweight='bold')

ax.legend(handles=[mNrmStE_lbl,mNrmTrg_lbl])
ax.legend(prop=dict(size=fsmid))

ax.set_xlim(xMin,mPlotMax * 1.1)
ax.set_ylim(GroFacMin,GroFacMax)

# If latex installed on system, plotting can look better 
if latexExists:
    ax.text(mPlotMax+0.01,1.01,"$\mathbb{E}_{t}[\mathbf{c}_{t+1}/\mathbf{c}_{t}]$",fontsize = fsmid,fontweight='bold')
    ax.text(mPlotMax*0.80,0.985+0.02*0,"$\leftarrow \mathbb{E}_{t}[\mathbf{m}_{t+1}/\mathbf{m}_{t}]$",fontsize = fsmid,fontweight='bold')
    ax.text(mPlotMax,0.998,r'$\pmb{\text{\TH}} = (\mathsf{R}\beta)^{1/\rho}$',fontsize = fsmid,fontweight='bold')
else:
    ax.text(mPlotMax+0.01,1.01,"$\mathsf{E}_{t}[\mathbf{c}_{t+1}/\mathbf{c}_{t}]$",fontsize = fsmid,fontweight='bold')
    ax.text(mPlotMax*0.80,0.985+0.02*0,"$\leftarrow \mathsf{E}_{t}[\mathbf{m}_{t+1}/\mathbf{m}_{t}]$",fontsize = fsmid,fontweight='bold')
    ax.text(mPlotMax,0.998,r'$\Phi = (\mathsf{\mathsf{R}}\beta)^{1/\rho}$',fontsize = fsmid,fontweight='bold')

# Ticks
ax.tick_params(labelbottom=False, labelleft=True,left='off',right='on',bottom='on',top='off')
plt.setp(ax.get_yticklabels(),fontsize=fssml)

ax.text(mPlotMax+0.01,1.029, r'$\Gamma$',fontsize = fsmid,fontweight='bold')
ax.set_ylabel('Growth Factors',fontsize = fsmid, fontweight='bold')

make('cGroTargetFig')

# %% [markdown]
# In the [interactive dashboard](#interactive-dashboard) see how target wealth changes when the consumer's time preference factor β or the growth factor Γ change.

# %% [markdown]
# ### [Consumption Function Bounds](https://www.econ2.jhu.edu/people/ccarroll/papers/BufferStockTheory/#AnalysisOfTheConvergedConsumptionFunction)
# [The next figure](https://www.econ2.jhu.edu/people/ccarroll/papers/BufferStockTheory/#cFuncBounds)
# illustrates theoretical bounds for the consumption function.
#
# We define two useful variables: lower bound of $\kappa$ (marginal propensity to consume) and limit of $h$ (Human wealth), along with some functions such as the limiting perfect foresight consumption function $\bar{c}(m)$, the upper bound function $\bar{\bar c}(m)$, and the lower bound function \underline{_c_}$(m)$.

# %%
# Define κ_Min, h_inf and PF consumption function, upper and lower bound of c function 

# Retrieve parameters (makes code below more readable)
R = Rfree      = baseAgent_Inf.Rfree
β = DiscFac    = baseAgent_Inf.DiscFac
ρ = CRRA       = baseAgent_Inf.CRRA
Γ = PermGro    = baseAgent_Inf.PermGroFac[0]
℘ = UnempPrb   = baseAgent_Inf.UnempPrb

mNrmTrg    = baseAgent_Inf.solution[0].mNrmTrg
mNrmStE    = baseAgent_Inf.solution[0].mNrmStE

κ_Min = 1.0-(R**(-1.0))*(R * β)**(1.0/ρ)
h_inf = (1.0/(1.0-Γ/R))

cFunc_Uncnst = lambda m: (h_inf -1)* κ_Min + κ_Min*m
cFunc_TopBnd = lambda m: (1 - ℘ ** (1/ρ)*(R*β)**(1.0/ρ)/R)*m
cFunc_BotBnd = lambda m: (1 -(R*β)**(1/ρ)/R) * m

# %%
# Plot the consumption function and its bounds

cMaxLabel=r'$\overline{c}(m)= (m-1+h)\underline{\kappa}$'
cMinLabel=r'Lower Bound: $\underline{c}(m)= (1-\pmb{\text{\TH}}_{R})\underline{\kappa}m$'
if not latexExists:
    cMaxLabel=r'$\overline{c}(m) = (m-1+h)κ̲' # Use unicode kludge
    cMinLabel=r'Lower Bound: c̲$(m)= (1-\Phi_{R})m = κ̲ m$'

mPlotMax = 25
mPlotMin = 0
# mKnk is point where the two upper bounds meet
mKnk = ((h_inf-1)* κ_Min)/((1 - UnempPrb**(1.0/CRRA)*(Rfree*DiscFac)**(1.0/CRRA)/Rfree)-κ_Min)
mBelwKnkPts = 300
mAbveKnkPts = 700
mBelwKnk = np.linspace(mPlotMin,mKnk,mBelwKnkPts)
mAbveKnk = np.linspace(mKnk,mPlotMax,mAbveKnkPts)
mFullPts = np.linspace(mPlotMin,mPlotMax,mBelwKnkPts+mAbveKnkPts)

plt.figure(figsize = (12,8))

plt.plot(mFullPts,baseAgent_Inf.solution[0].cFunc(mFullPts), color="black")
plt.plot(mBelwKnk,cFunc_Uncnst(mBelwKnk)          , color="black",linestyle="--")
plt.plot(mAbveKnk,cFunc_Uncnst(mAbveKnk)          , color="black",linewidth=2.5)
plt.plot(mBelwKnk,cFunc_TopBnd(mBelwKnk)          , color="black",linewidth=2.5)
plt.plot(mAbveKnk,cFunc_TopBnd(mAbveKnk)          , color="black",linestyle="--")
plt.plot(mBelwKnk,cFunc_BotBnd(mBelwKnk)          , color="black",linewidth=2.5)
plt.plot(mAbveKnk,cFunc_BotBnd(mAbveKnk)          , color="black",linewidth=2.5)
plt.tick_params(labelbottom=False, labelleft=False,left='off',right='off',bottom='off',top='off')
plt.xlim(mPlotMin,mPlotMax)
plt.ylim(mPlotMin,1.12*cFunc_Uncnst(mPlotMax))
plt.text(mPlotMin,1.12*cFunc_Uncnst(mPlotMax)+0.05,"$c$",fontsize = 22)
plt.text(mPlotMax+0.1,mPlotMin,"$m$",fontsize = 22)
plt.text(2.5,1,r'$c(m)$',fontsize = 22,fontweight='bold')
if latexExists:
    plt.text(6,5,r'$\overline{\overline{c}}(m)= \overline{\kappa}m = (1-\wp^{1/\rho}\pmb{\text{\TH}}_{R})m$',fontsize = 22,fontweight='bold')
else:
    plt.text(6,5,r'$\overline{\overline{c}}(m)= \overline{\kappa}m = (1-\wp^{1/\rho}\Phi_{R})m$',fontsize = 22,fontweight='bold')
plt.text(2.10,3.8, cMaxLabel,fontsize = 22,fontweight='bold')
plt.text(9,4.1,r'Upper Bound $ = $ Min $[\overline{\overline{c}}(m),\overline{c}(m)]$',fontsize = 22,fontweight='bold')
plt.text(8,0.9,cMinLabel,fontsize = 22,fontweight='bold')
plt.arrow(2.45,1.05,-0.5,0.02,head_width= 0.05,width=0.001,facecolor='black',length_includes_head='True')
plt.arrow(2.15,3.88,-0.5,0.1,head_width= 0.05,width=0.001,facecolor='black',length_includes_head='True')
plt.arrow(8.95,4.20,-0.8,0.05,head_width= 0.1,width=0.015,facecolor='black',length_includes_head='True')
plt.arrow(5.95,5.05,-0.4,mPlotMin,head_width= 0.05,width=0.001,facecolor='black',length_includes_head='True')
plt.arrow(14,0.70,0.5,-0.1,head_width= 0.05,width=0.001,facecolor='black',length_includes_head='True')


make('cFuncBounds')

# %% [markdown]
# ### [Upper and Lower Limits of the Marginal Propensity to Consume](https://www.econ2.jhu.edu/people/ccarroll/papers/BufferStockTheory/#MPCLimits)
#
# The paper shows that as $m_{t}~\uparrow~\infty$ the consumption function in the presence of risk gets arbitrarily close to the perfect foresight consumption function.  Defining \underline{κ}
# as the perfect foresight model's MPC, this implies that $\lim_{m_{t}~\uparrow~\infty} c^{\prime}(m) = $ \underline{κ}
# .
#
# The paper also derives an analytical limit $\bar{\kappa}$ for the MPC as $m$ approaches 0., its bounding value.  Strict concavity of the consumption function implies that the consumption function will be everywhere below a function $\bar{\kappa}m$, and strictly declining everywhere.  The last figure plots the MPC between these two limits.

# %%
# The last figure shows the upper and lower limits of the MPC

# Retrieve parameters (makes code readable)
Rfree      = baseAgent_Inf.Rfree
DiscFac    = baseAgent_Inf.DiscFac
CRRA       = baseAgent_Inf.CRRA
PermGro    = baseAgent_Inf.PermGroFac[0]
mNrmTrg    = baseAgent_Inf.solution[0].mNrmTrg
mNrmStE    = baseAgent_Inf.solution[0].mNrmStE
UnempPrb   = baseAgent_Inf.UnempPrb

mPlotMax=8    

plt.figure(figsize = (12,8))
# Set the plot range of m
m = np.linspace(0.001,mPlotMax,mPts)

# Use the HARK method derivative to get the derivative of cFunc, and which constitutes the MPC
MPC = baseAgent_Inf.solution[0].cFunc.derivative(m)

# Define the upper bound of MPC
κ_Max = (1 - UnempPrb ** (1.0/CRRA)*(Rfree*DiscFac)**(1.0/CRRA)/Rfree)

# Define the lower bound of MPC
MPCLower = κ_Min

kappaDef=r'$\underline{\kappa}\equiv(1-\pmb{\text{\TH}}_{R})$'
if not latexExists:
    kappaDef=r'κ̲$\equiv(1-\Phi_{R})$'

plt.plot(m,MPC,color = 'black')
plt.plot([mPlotMin,mPlotMax],[κ_Max,κ_Max],color = 'black')
plt.plot([mPlotMin,mPlotMax],[κ_Min,κ_Min],color = 'black')
plt.xlim(mPlotMin,mPlotMax)
plt.ylim(0,1) # MPC bounds are between 0 and 1 
plt.text(1.5,0.6,r'$\kappa(m) \equiv c^{\prime}(m)$',fontsize = 26,fontweight='bold')
if latexExists:
    plt.text(5,0.87,r'$(1-\wp^{1/\rho}\pmb{\text{\TH}})\equiv \overline{\kappa}$',fontsize = 26,fontweight='bold') # Use Thorn character
else:
    plt.text(5,0.87,r'$(1-\wp^{1/\rho}\Phi_{R})\equiv \overline{\kappa}$',fontsize = 26,fontweight='bold') # Use Phi instead of Thorn (alas)

plt.text(0.5,0.07,kappaDef,fontsize = 26,fontweight='bold')
plt.text(mPlotMax+0.05,mPlotMin,"$m$",fontsize = 26)
plt.arrow(1.45,0.61,-0.4,mPlotMin,head_width= 0.02,width=0.001,facecolor='black',length_includes_head='True')
plt.arrow(2.2,0.07,0.2,-0.01,head_width= 0.02,width=0.001,facecolor='black',length_includes_head='True')
plt.arrow(4.95,0.895,-0.2,0.03,head_width= 0.02,width=0.001,facecolor='black',length_includes_head='True')

make('MPCLimits')

# %% [markdown]
# # Summary
#
# [Two tables in the paper](https://econ-ark.github.io/BufferStockTheory/#Factors-Defined-And-Compared) summarize the various definitions, and then articulate conditions required for the problem to have a nondegenerate solution.  Among the nondegenerate cases, the most interesting result is that if the Growth Impatience Condition holds there will be a target level of wealth.

# %% [markdown]
# ### Appendix: Options for Interacting With This Notebook <a id='optionsForInstalling'></a>
#
# 1. [View (static version)](https://github.com/llorracc/BufferStockTheory/blob/master/Code/Python/BufferStockTheory.ipynb) on GitHub (warning:  GitHub does not render Jupyter notebooks reliably)
# 1. [Launch Online Interactive Version](https://econ-ark.org/materials/BufferStockTheory/#launch)
# 1. For fast (local) execution, install [econ-ark](http://github.com/econ-ark) on your computer ([QUICK START GUIDE](https://github.com/econ-ark/HARK/blob/master/README.md)) then follow these instructions to retrieve the full contents of the `BufferStockTheory` [REMARK](https://github.com/econ-ark/REMARK):
#    1. At a command line, change the working directory to the one where you want to install
#        * On unix, if you install in the `/tmp` directory, the installation will disappear after a reboot:
#        * `cd /tmp`
#    1. `git clone https://github.com/econ-ark/REMARK --recursive`
#    1. `cd REMARK/REMARKs/BufferStockTheory`
#    1. `jupyter notebook BufferStockTheory.ipynb`

# %% [markdown]
# ### Appendix: Perfect foresight agent failing both the FHWC and RIC

# %%
from copy import copy
from HARK.ConsumptionSaving.ConsIndShockModel import PerfForesightConsumerType
fig6_par = copy(base_params)

# Replace parameters.
fig6_par['Rfree'] = 0.98
fig6_par['DiscFac'] = 1
fig6_par['PermGroFac'] = [0.99]
fig6_par['CRRA'] = 2
fig6_par['BoroCnstArt']  = 0
fig6_par['T_cycle'] = 0
fig6_par['cycles'] = 0
fig6_par['quiet'] = False

# Create the agent
RichButPatientAgent = PerfForesightConsumerType(**fig6_par)
# Check conditions
RichButPatientAgent.check_conditions(verbose = 3)
# Solve
RichButPatientAgent.solve()

# Plot
mPlotMin, mPlotMax = 1, 9.5
plt.figure(figsize = (8,4))
m_grid = np.linspace(mPlotMin,mPlotMax,500)
plt.plot(m_grid-1, RichButPatientAgent.solution[0].cFunc(m_grid), color="black")
plt.text(mPlotMax-1+0.05,1,r"$b$",fontsize = 26)
plt.text(mPlotMin-1,1.017,r"$c$",fontsize = 26)
plt.xlim(mPlotMin-1,mPlotMax-1)
plt.ylim(mPlotMin,1.016)

make('PFGICRawHoldsFHWCFailsRICFails')

# %% [markdown]
# ----------------------------------------------------------
